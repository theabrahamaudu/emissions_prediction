# %%
# Import modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools
import datetime as dt

from tqdm.notebook import tqdm
tqdm.pandas()

# Set Pandas options
pd.set_option('max_columns', None)
pd.set_option('max_rows', 999)

# statistical tests
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import grangercausalitytests

# Model building
from statsmodels.tsa.api import VAR
from statsmodels.tsa.statespace.varmax import VARMAX

# Model Evaluation
from sklearn.metrics import mean_squared_error
import math
from statistics import mean

# skip warning messages
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the dataset
dataset = pd.read_csv("Total Emissions Per Country (2000-2020).csv")

# %%
# Preview the dataset
dataset.head()
# Out:
#           Area           Item                           Element        Unit  \
# 0  Afghanistan  Crop Residues            Direct emissions (N2O)  kilotonnes
# 1  Afghanistan  Crop Residues          Indirect emissions (N2O)  kilotonnes
# 2  Afghanistan  Crop Residues                   Emissions (N2O)  kilotonnes
# 3  Afghanistan  Crop Residues  Emissions (CO2eq) from N2O (AR5)  kilotonnes
# 4  Afghanistan  Crop Residues           Emissions (CO2eq) (AR5)  kilotonnes
#
#       2000      2001      2002      2003      2004      2005      2006  \
# 0    0.520    0.5267    0.8200    0.9988    0.8225    1.1821    1.0277
# 1    0.117    0.1185    0.1845    0.2247    0.1851    0.2660    0.2312
# 2    0.637    0.6452    1.0045    1.2235    1.0075    1.4481    1.2589
# 3  168.807  170.9884  266.1975  324.2195  266.9995  383.7498  333.6093
# 4  168.807  170.9884  266.1975  324.2195  266.9995  383.7498  333.6093
#
#        2007      2008      2009      2010      2011      2012      2013  \
# 0    1.2426    0.8869    1.3920    1.2742    1.0321    1.3726    1.4018
# 1    0.2796    0.1996    0.3132    0.2867    0.2322    0.3088    0.3154
# 2    1.5222    1.0865    1.7051    1.5609    1.2643    1.6815    1.7173
# 3  403.3749  287.9099  451.8647  413.6467  335.0379  445.5958  455.0727
# 4  403.3749  287.9099  451.8647  413.6467  335.0379  445.5958  455.0727
#
#        2014      2015      2016      2017      2018      2019      2020
# 0    1.4584    1.2424    1.1940    1.0617    0.8988    1.2176    1.3170
# 1    0.3281    0.2795    0.2687    0.2389    0.2022    0.2740    0.2963
# 2    1.7865    1.5220    1.4627    1.3005    1.1011    1.4916    1.6133
# 3  473.4174  403.3181  387.6130  344.6447  291.7838  395.2689  427.5284
# 4  473.4174  403.3181  387.6130  344.6447  291.7838  395.2689  427.5284

# %%
# AMke a copy of the dataset for wrangling
data = dataset.copy()

# %%
# check for empty data points
data.isnull().sum()
# Out:
# Area          0
# Item          0
# Element       0
# Unit          0
# 2000       3188
# 2001       4727
# 2002       4628
# 2003       4607
# 2004       4602
# 2005       4334
# 2006       4292
# 2007       4450
# 2008       4469
# 2009       4482
# 2010       4051
# 2011       4629
# 2012       4151
# 2013       4264
# 2014       4386
# 2015       4476
# 2016       4513
# 2017       4689
# 2018       4741
# 2019       4777
# 2020       5094
# dtype: int64

# %%
# drop empty data points
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# Area       0
# Item       0
# Element    0
# Unit       0
# 2000       0
# 2001       0
# 2002       0
# 2003       0
# 2004       0
# 2005       0
# 2006       0
# 2007       0
# 2008       0
# 2009       0
# 2010       0
# 2011       0
# 2012       0
# 2013       0
# 2014       0
# 2015       0
# 2016       0
# 2017       0
# 2018       0
# 2019       0
# 2020       0
# dtype: int64

# %%
data.shape
# Out:
# (52692, 25)

# %%
# check for duplicates
data.duplicated().sum()
# Out:
# 2

# %%
# drop duplicates
data = data.drop_duplicates()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52690 entries, 0 to 58764
# Data columns (total 25 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Area     52690 non-null  object
#  1   Item     52690 non-null  object
#  2   Element  52690 non-null  object
#  3   Unit     52690 non-null  object
#  4   2000     52690 non-null  float64
#  5   2001     52690 non-null  float64
#  6   2002     52690 non-null  float64
#  7   2003     52690 non-null  float64
#  8   2004     52690 non-null  float64
#  9   2005     52690 non-null  float64
#  10  2006     52690 non-null  float64
#  11  2007     52690 non-null  float64
#  12  2008     52690 non-null  float64
#  13  2009     52690 non-null  float64
#  14  2010     52690 non-null  float64
#  15  2011     52690 non-null  float64
#  16  2012     52690 non-null  float64
#  17  2013     52690 non-null  float64
#  18  2014     52690 non-null  float64
#  19  2015     52690 non-null  float64
#  20  2016     52690 non-null  float64
#  21  2017     52690 non-null  float64
#  22  2018     52690 non-null  float64
#  23  2019     52690 non-null  float64
#  24  2020     52690 non-null  float64
# dtypes: float64(21), object(4)
# memory usage: 10.5+ MB

# %%
data
# Out:
#               Area                        Item  \
# 0      Afghanistan               Crop Residues
# 1      Afghanistan               Crop Residues
# 2      Afghanistan               Crop Residues
# 3      Afghanistan               Crop Residues
# 4      Afghanistan               Crop Residues
# ...            ...                         ...
# 58760         OECD  All sectors without LULUCF
# 58761         OECD  All sectors without LULUCF
# 58762         OECD  All sectors without LULUCF
# 58763         OECD  All sectors without LULUCF
# 58764         OECD  All sectors without LULUCF
#
#                                     Element        Unit          2000  \
# 0                    Direct emissions (N2O)  kilotonnes  5.200000e-01
# 1                  Indirect emissions (N2O)  kilotonnes  1.170000e-01
# 2                           Emissions (N2O)  kilotonnes  6.370000e-01
# 3          Emissions (CO2eq) from N2O (AR5)  kilotonnes  1.688070e+02
# 4                   Emissions (CO2eq) (AR5)  kilotonnes  1.688070e+02
# ...                                     ...         ...           ...
# 58760                       Emissions (CO2)  kilotonnes  1.334328e+07
# 58761  Emissions (CO2eq) from F-gases (AR5)  kilotonnes  3.941893e+05
# 58762      Emissions (CO2eq) from CH4 (AR5)  kilotonnes  2.145052e+06
# 58763      Emissions (CO2eq) from N2O (AR5)  kilotonnes  8.535273e+05
# 58764               Emissions (CO2eq) (AR5)  kilotonnes  1.673605e+07
#
#                2001          2002          2003          2004          2005  \
# 0      5.267000e-01  8.200000e-01  9.988000e-01  8.225000e-01  1.182100e+00
# 1      1.185000e-01  1.845000e-01  2.247000e-01  1.851000e-01  2.660000e-01
# 2      6.452000e-01  1.004500e+00  1.223500e+00  1.007500e+00  1.448100e+00
# 3      1.709884e+02  2.661975e+02  3.242195e+02  2.669995e+02  3.837498e+02
# 4      1.709884e+02  2.661975e+02  3.242195e+02  2.669995e+02  3.837498e+02
# ...             ...           ...           ...           ...           ...
# 58760  1.326305e+07  1.332979e+07  1.352237e+07  1.366651e+07  1.369481e+07
# 58761  3.882647e+05  4.176531e+05  4.392191e+05  4.672796e+05  5.080909e+05
# 58762  2.126567e+06  2.093083e+06  2.038232e+06  2.047953e+06  2.008645e+06
# 58763  8.496131e+05  8.400758e+05  8.124412e+05  8.328157e+05  8.123489e+05
# 58764  1.662750e+07  1.668060e+07  1.681226e+07  1.701456e+07  1.702390e+07
#
#                2006          2007          2008          2009          2010  \
# 0      1.027700e+00  1.242600e+00  8.869000e-01  1.392000e+00  1.274200e+00
# 1      2.312000e-01  2.796000e-01  1.996000e-01  3.132000e-01  2.867000e-01
# 2      1.258900e+00  1.522200e+00  1.086500e+00  1.705100e+00  1.560900e+00
# 3      3.336093e+02  4.033749e+02  2.879099e+02  4.518647e+02  4.136467e+02
# 4      3.336093e+02  4.033749e+02  2.879099e+02  4.518647e+02  4.136467e+02
# ...             ...           ...           ...           ...           ...
# 58760  1.369710e+07  1.379770e+07  1.358338e+07  1.273838e+07  1.311391e+07
# 58761  5.511406e+05  5.902422e+05  6.271651e+05  6.774160e+05  7.641415e+05
# 58762  2.039932e+06  2.035230e+06  2.016547e+06  1.965772e+06  1.931536e+06
# 58763  8.257754e+05  8.312711e+05  7.887649e+05  7.878419e+05  7.864163e+05
# 58764  1.711395e+07  1.725445e+07  1.701586e+07  1.616941e+07  1.659600e+07
#
#                2011          2012          2013          2014          2015  \
# 0      1.032100e+00  1.372600e+00  1.401800e+00  1.458400e+00  1.242400e+00
# 1      2.322000e-01  3.088000e-01  3.154000e-01  3.281000e-01  2.795000e-01
# 2      1.264300e+00  1.681500e+00  1.717300e+00  1.786500e+00  1.522000e+00
# 3      3.350379e+02  4.455958e+02  4.550727e+02  4.734174e+02  4.033181e+02
# 4      3.350379e+02  4.455958e+02  4.550727e+02  4.734174e+02  4.033181e+02
# ...             ...           ...           ...           ...           ...
# 58760  1.289801e+07  1.270146e+07  1.274243e+07  1.261664e+07  1.253301e+07
# 58761  7.759070e+05  7.826597e+05  8.006688e+05  8.326775e+05  8.546258e+05
# 58762  1.980459e+06  1.971959e+06  1.922551e+06  1.934854e+06  1.924370e+06
# 58763  8.344119e+05  8.490201e+05  8.204159e+05  8.325680e+05  8.289014e+05
# 58764  1.648879e+07  1.630510e+07  1.628606e+07  1.621674e+07  1.614090e+07
#
#                2016          2017          2018          2019          2020
# 0      1.194000e+00  1.061700e+00  8.988000e-01  1.217600e+00  1.317000e+00
# 1      2.687000e-01  2.389000e-01  2.022000e-01  2.740000e-01  2.963000e-01
# 2      1.462700e+00  1.300500e+00  1.101100e+00  1.491600e+00  1.613300e+00
# 3      3.876130e+02  3.446447e+02  2.917838e+02  3.952689e+02  4.275284e+02
# 4      3.876130e+02  3.446447e+02  2.917838e+02  3.952689e+02  4.275284e+02
# ...             ...           ...           ...           ...           ...
# 58760  1.241227e+07  1.243658e+07  1.254684e+07  1.217070e+07  1.088919e+07
# 58761  8.741566e+05  8.884415e+05  9.049044e+05  9.172806e+05  9.208261e+05
# 58762  1.880327e+06  1.915982e+06  1.923635e+06  1.882769e+06  1.825476e+06
# 58763  8.218071e+05  8.400423e+05  8.349622e+05  8.118189e+05  8.009744e+05
# 58764  1.598856e+07  1.608104e+07  1.621034e+07  1.578256e+07  1.443647e+07
#
# [52690 rows x 25 columns]

# %%
# find number of categories in categorical values
categorical_features = [feature for feature in data.columns if data[feature].dtype=='O']

# %%
categorical_features
# Out:
# ['Area', 'Item', 'Element', 'Unit']

# %%
for feature in categorical_features:
    print(f"Number of categories in {feature}: ", data[feature].nunique())
    print(f"Names of categories in {feature}: ", data[feature].unique(),"\n")
# Out:
# Number of categories in Area:  268
# Names of categories in Area:  ['Afghanistan' 'Albania' 'Algeria' 'American Samoa' 'Andorra' 'Angola'
#  'Anguilla' 'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba'
#  'Australia' 'Austria' 'Azerbaijan' 'Bahamas' 'Bahrain' 'Bangladesh'
#  'Barbados' 'Belarus' 'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan'
#  'Bolivia (Plurinational State of)' 'Bosnia and Herzegovina' 'Botswana'
#  'Brazil' 'British Virgin Islands' 'Brunei Darussalam' 'Bulgaria'
#  'Burkina Faso' 'Burundi' 'Cabo Verde' 'Cambodia' 'Cameroon' 'Canada'
#  'Cayman Islands' 'Central African Republic' 'Chad' 'Channel Islands'
#  'Chile' 'China' 'China, Hong Kong SAR' 'China, Macao SAR'
#  'China, mainland' 'China, Taiwan Province of' 'Colombia' 'Comoros'
#  'Congo' 'Cook Islands' 'Costa Rica' "C?e d'Ivoire" 'Croatia' 'Cuba'
#  'Cyprus' 'Czechia' "Democratic People's Republic of Korea"
#  'Democratic Republic of the Congo' 'Denmark' 'Djibouti' 'Dominica'
#  'Dominican Republic' 'Ecuador' 'Egypt' 'El Salvador' 'Equatorial Guinea'
#  'Eritrea' 'Estonia' 'Eswatini' 'Ethiopia' 'Falkland Islands (Malvinas)'
#  'Faroe Islands' 'Fiji' 'Finland' 'France' 'French Guyana'
#  'French Polynesia' 'Gabon' 'Gambia' 'Georgia' 'Germany' 'Ghana'
#  'Gibraltar' 'Greece' 'Greenland' 'Grenada' 'Guadeloupe' 'Guam'
#  'Guatemala' 'Guinea' 'Guinea-Bissau' 'Guyana' 'Haiti' 'Holy See'
#  'Honduras' 'Hungary' 'Iceland' 'India' 'Indonesia'
#  'Iran (Islamic Republic of)' 'Iraq' 'Ireland' 'Isle of Man' 'Israel'
#  'Italy' 'Jamaica' 'Japan' 'Jordan' 'Kazakhstan' 'Kenya' 'Kiribati'
#  'Kuwait' 'Kyrgyzstan' "Lao People's Democratic Republic" 'Latvia'
#  'Lebanon' 'Lesotho' 'Liberia' 'Libya' 'Liechtenstein' 'Lithuania'
#  'Luxembourg' 'Madagascar' 'Malawi' 'Malaysia' 'Maldives' 'Mali' 'Malta'
#  'Marshall Islands' 'Martinique' 'Mauritania' 'Mauritius' 'Mayotte'
#  'Mexico' 'Micronesia (Federated States of)' 'Monaco' 'Mongolia'
#  'Montserrat' 'Morocco' 'Mozambique' 'Myanmar' 'Namibia' 'Nauru' 'Nepal'
#  'Netherlands' 'Netherlands Antilles (former)' 'New Caledonia'
#  'New Zealand' 'Nicaragua' 'Niger' 'Nigeria' 'Niue' 'Norfolk Island'
#  'North Macedonia' 'Northern Mariana Islands' 'Norway' 'Oman' 'Pakistan'
#  'Palau' 'Palestine' 'Panama' 'Papua New Guinea' 'Paraguay' 'Peru'
#  'Philippines' 'Pitcairn' 'Poland' 'Portugal' 'Puerto Rico' 'Qatar'
#  'Republic of Korea' 'Republic of Moldova' 'R?nion' 'Romania'
#  'Russian Federation' 'Rwanda'
#  'Saint Helena, Ascension and Tristan da Cunha' 'Saint Kitts and Nevis'
#  'Saint Lucia' 'Saint Pierre and Miquelon'
#  'Saint Vincent and the Grenadines' 'Samoa' 'San Marino'
#  'Sao Tome and Principe' 'Saudi Arabia' 'Senegal' 'Seychelles'
#  'Sierra Leone' 'Singapore' 'Slovakia' 'Slovenia' 'Solomon Islands'
#  'Somalia' 'South Africa' 'Spain' 'Sri Lanka' 'Suriname'
#  'Svalbard and Jan Mayen Islands' 'Sweden' 'Switzerland'
#  'Syrian Arab Republic' 'Tajikistan' 'Thailand' 'Timor-Leste' 'Togo'
#  'Tokelau' 'Tonga' 'Trinidad and Tobago' 'Tunisia' 'T?kiye' 'Turkmenistan'
#  'Turks and Caicos Islands' 'Tuvalu' 'Uganda' 'Ukraine'
#  'United Arab Emirates'
#  'United Kingdom of Great Britain and Northern Ireland'
#  'United Republic of Tanzania' 'United States of America'
#  'United States Virgin Islands' 'Uruguay' 'Uzbekistan' 'Vanuatu'
#  'Venezuela (Bolivarian Republic of)' 'Viet Nam'
#  'Wallis and Futuna Islands' 'Western Sahara' 'Yemen' 'Zambia' 'Zimbabwe'
#  'World' 'Africa' 'Eastern Africa' 'Middle Africa' 'Northern Africa'
#  'Southern Africa' 'Western Africa' 'Americas' 'Northern America'
#  'Central America' 'Caribbean' 'South America' 'Asia' 'Central Asia'
#  'Eastern Asia' 'Southern Asia' 'South-eastern Asia' 'Western Asia'
#  'Europe' 'Eastern Europe' 'Northern Europe' 'Southern Europe'
#  'Western Europe' 'Oceania' 'Australia and New Zealand' 'Melanesia'
#  'Micronesia' 'Polynesia' 'European Union (27)'
#  'Least Developed Countries' 'Land Locked Developing Countries'
#  'Small Island Developing States' 'Low Income Food Deficit Countries'
#  'Net Food Importing Developing Countries' 'Annex I countries'
#  'Non-Annex I countries' 'OECD']
#
# Number of categories in Item:  42
# Names of categories in Item:  ['Crop Residues' 'Rice Cultivation' 'Burning - Crop residues'
#  'Enteric Fermentation' 'Manure Management' 'Manure left on Pasture'
#  'Manure applied to Soils' 'Synthetic Fertilizers' 'Drained organic soils'
#  'Drained organic soils (CO2)' 'Drained organic soils (N2O)'
#  'On-farm energy use' 'Forestland' 'Net Forest conversion' 'Savanna fires'
#  'Fires in organic soils' 'Forest fires' 'Fires in humid tropical forests'
#  'Waste - agri-food systems' 'Fertilizers Manufacturing'
#  'On-farm electricity use' 'Food Processing' 'Food Packaging'
#  'Food Retail' 'Food Household Consumption' 'Food Transport' 'Energy'
#  'IPPU' 'Waste' 'Other' 'Farm-gate emissions' 'Land Use change'
#  'Emissions on agricultural land' 'Pre- and post- production'
#  'Agri-food systems' 'IPCC Agriculture' 'Agricultural Soils' 'LULUCF'
#  'AFOLU' 'All sectors with LULUCF' 'All sectors without LULUCF'
#  'International bunkers']
#
# Number of categories in Element:  9
# Names of categories in Element:  ['Direct emissions (N2O)' 'Indirect emissions (N2O)' 'Emissions (N2O)'
#  'Emissions (CO2eq) from N2O (AR5)' 'Emissions (CO2eq) (AR5)'
#  'Emissions (CH4)' 'Emissions (CO2eq) from CH4 (AR5)' 'Emissions (CO2)'
#  'Emissions (CO2eq) from F-gases (AR5)']
#
# Number of categories in Unit:  1
# Names of categories in Unit:  ['kilotonnes']

# %% [markdown]
# From this separation, we can see that tracking emissions by category will be quite cumbersome as there are 42 categories and as such, it will be better to classify by Element which has 9 just unique values.

# %%
# Stack the years in one column to simplify the data
stacked_yr_data = pd.melt(data, 
               id_vars=['Area', 'Item', 'Element'],
               value_vars=data.iloc[:,4:],
               var_name='Year',
               value_name='Total_Emissions_KT'
)

# %%
stacked_yr_data
# Out:
#                 Area                        Item  \
# 0        Afghanistan               Crop Residues
# 1        Afghanistan               Crop Residues
# 2        Afghanistan               Crop Residues
# 3        Afghanistan               Crop Residues
# 4        Afghanistan               Crop Residues
# ...              ...                         ...
# 1106485         OECD  All sectors without LULUCF
# 1106486         OECD  All sectors without LULUCF
# 1106487         OECD  All sectors without LULUCF
# 1106488         OECD  All sectors without LULUCF
# 1106489         OECD  All sectors without LULUCF
#
#                                       Element  Year  Total_Emissions_KT
# 0                      Direct emissions (N2O)  2000        5.200000e-01
# 1                    Indirect emissions (N2O)  2000        1.170000e-01
# 2                             Emissions (N2O)  2000        6.370000e-01
# 3            Emissions (CO2eq) from N2O (AR5)  2000        1.688070e+02
# 4                     Emissions (CO2eq) (AR5)  2000        1.688070e+02
# ...                                       ...   ...                 ...
# 1106485                       Emissions (CO2)  2020        1.088919e+07
# 1106486  Emissions (CO2eq) from F-gases (AR5)  2020        9.208261e+05
# 1106487      Emissions (CO2eq) from CH4 (AR5)  2020        1.825476e+06
# 1106488      Emissions (CO2eq) from N2O (AR5)  2020        8.009744e+05
# 1106489               Emissions (CO2eq) (AR5)  2020        1.443647e+07
#
# [1106490 rows x 5 columns]

# %%
# plot the overall progression of emissions globally by year just to get a sense of the data
plt.figure(figsize=(16,9))
stacked_yr_data.groupby(['Year'])['Total_Emissions_KT'].sum().plot.bar()
plt.xlabel('Year')
plt.ylabel('Total Emissions (KT)')
# Out:
# Text(0, 0.5, 'Total Emissions (KT)')

# %% [markdown]
# ###### Use Afghanistan data as sample for generalization later on

# %%
# Get afghanistan data from data
afghanistan_data = stacked_yr_data[stacked_yr_data['Area']=='Afghanistan']

# %%
afghanistan_data.head(500)
# Out:
#                Area                             Item  \
# 0       Afghanistan                    Crop Residues
# 1       Afghanistan                    Crop Residues
# 2       Afghanistan                    Crop Residues
# 3       Afghanistan                    Crop Residues
# 4       Afghanistan                    Crop Residues
# 5       Afghanistan                 Rice Cultivation
# 6       Afghanistan                 Rice Cultivation
# 7       Afghanistan                 Rice Cultivation
# 8       Afghanistan          Burning - Crop residues
# 9       Afghanistan          Burning - Crop residues
# 10      Afghanistan          Burning - Crop residues
# 11      Afghanistan          Burning - Crop residues
# 12      Afghanistan          Burning - Crop residues
# 13      Afghanistan             Enteric Fermentation
# 14      Afghanistan             Enteric Fermentation
# 15      Afghanistan             Enteric Fermentation
# 16      Afghanistan                Manure Management
# 17      Afghanistan                Manure Management
# 18      Afghanistan                Manure Management
# 19      Afghanistan                Manure Management
# 20      Afghanistan                Manure Management
# 21      Afghanistan           Manure left on Pasture
# 22      Afghanistan           Manure left on Pasture
# 23      Afghanistan           Manure left on Pasture
# 24      Afghanistan           Manure left on Pasture
# 25      Afghanistan           Manure left on Pasture
# 26      Afghanistan          Manure applied to Soils
# 27      Afghanistan          Manure applied to Soils
# 28      Afghanistan          Manure applied to Soils
# 29      Afghanistan          Manure applied to Soils
# 30      Afghanistan          Manure applied to Soils
# 31      Afghanistan            Synthetic Fertilizers
# 32      Afghanistan            Synthetic Fertilizers
# 33      Afghanistan            Synthetic Fertilizers
# 34      Afghanistan            Synthetic Fertilizers
# 35      Afghanistan            Synthetic Fertilizers
# 36      Afghanistan            Drained organic soils
# 37      Afghanistan      Drained organic soils (CO2)
# 38      Afghanistan      Drained organic soils (CO2)
# 39      Afghanistan      Drained organic soils (N2O)
# 40      Afghanistan      Drained organic soils (N2O)
# 41      Afghanistan      Drained organic soils (N2O)
# 42      Afghanistan               On-farm energy use
# 43      Afghanistan               On-farm energy use
# 44      Afghanistan               On-farm energy use
# 45      Afghanistan               On-farm energy use
# 46      Afghanistan               On-farm energy use
# 47      Afghanistan               On-farm energy use
# 48      Afghanistan                       Forestland
# 49      Afghanistan                       Forestland
# 50      Afghanistan            Net Forest conversion
# 51      Afghanistan            Net Forest conversion
# 52      Afghanistan                    Savanna fires
# 53      Afghanistan                    Savanna fires
# 54      Afghanistan                    Savanna fires
# 55      Afghanistan                    Savanna fires
# 56      Afghanistan                    Savanna fires
# 57      Afghanistan           Fires in organic soils
# 58      Afghanistan           Fires in organic soils
# 59      Afghanistan           Fires in organic soils
# 60      Afghanistan           Fires in organic soils
# 61      Afghanistan                     Forest fires
# 62      Afghanistan                     Forest fires
# 63      Afghanistan                     Forest fires
# 64      Afghanistan                     Forest fires
# 65      Afghanistan                     Forest fires
# 66      Afghanistan  Fires in humid tropical forests
# 67      Afghanistan  Fires in humid tropical forests
# 68      Afghanistan  Fires in humid tropical forests
# 69      Afghanistan  Fires in humid tropical forests
# 70      Afghanistan  Fires in humid tropical forests
# 71      Afghanistan        Waste - agri-food systems
# 72      Afghanistan        Waste - agri-food systems
# 73      Afghanistan        Waste - agri-food systems
# 74      Afghanistan        Waste - agri-food systems
# 75      Afghanistan        Waste - agri-food systems
# 76      Afghanistan        Waste - agri-food systems
# 77      Afghanistan        Fertilizers Manufacturing
# 78      Afghanistan        Fertilizers Manufacturing
# 79      Afghanistan          On-farm electricity use
# 80      Afghanistan          On-farm electricity use
# 81      Afghanistan          On-farm electricity use
# 82      Afghanistan          On-farm electricity use
# 83      Afghanistan          On-farm electricity use
# 84      Afghanistan          On-farm electricity use
# 85      Afghanistan                  Food Processing
# 86      Afghanistan                  Food Processing
# 87      Afghanistan                  Food Processing
# 88      Afghanistan                  Food Processing
# 89      Afghanistan                  Food Processing
# 90      Afghanistan                  Food Processing
# 91      Afghanistan                   Food Packaging
# 92      Afghanistan                   Food Packaging
# 93      Afghanistan                   Food Packaging
# 94      Afghanistan                   Food Packaging
# 95      Afghanistan                   Food Packaging
# 96      Afghanistan                   Food Packaging
# 97      Afghanistan                      Food Retail
# 98      Afghanistan                      Food Retail
# 99      Afghanistan                      Food Retail
# 100     Afghanistan                      Food Retail
# 101     Afghanistan                      Food Retail
# 102     Afghanistan                      Food Retail
# 103     Afghanistan       Food Household Consumption
# 104     Afghanistan       Food Household Consumption
# 105     Afghanistan       Food Household Consumption
# 106     Afghanistan       Food Household Consumption
# 107     Afghanistan       Food Household Consumption
# 108     Afghanistan       Food Household Consumption
# 109     Afghanistan                   Food Transport
# 110     Afghanistan                   Food Transport
# 111     Afghanistan                   Food Transport
# 112     Afghanistan                   Food Transport
# 113     Afghanistan                   Food Transport
# 114     Afghanistan                   Food Transport
# 115     Afghanistan                           Energy
# 116     Afghanistan                           Energy
# 117     Afghanistan                           Energy
# 118     Afghanistan                           Energy
# 119     Afghanistan                           Energy
# 120     Afghanistan                           Energy
# 121     Afghanistan                             IPPU
# 122     Afghanistan                             IPPU
# 123     Afghanistan                             IPPU
# 124     Afghanistan                             IPPU
# 125     Afghanistan                            Waste
# 126     Afghanistan                            Waste
# 127     Afghanistan                            Waste
# 128     Afghanistan                            Waste
# 129     Afghanistan                            Waste
# 130     Afghanistan                            Other
# 131     Afghanistan                            Other
# 132     Afghanistan                            Other
# 133     Afghanistan              Farm-gate emissions
# 134     Afghanistan              Farm-gate emissions
# 135     Afghanistan              Farm-gate emissions
# 136     Afghanistan              Farm-gate emissions
# 137     Afghanistan              Farm-gate emissions
# 138     Afghanistan              Farm-gate emissions
# 139     Afghanistan              Farm-gate emissions
# 140     Afghanistan              Farm-gate emissions
# 141     Afghanistan                  Land Use change
# 142     Afghanistan                  Land Use change
# 143     Afghanistan                  Land Use change
# 144     Afghanistan                  Land Use change
# 145     Afghanistan                  Land Use change
# 146     Afghanistan                  Land Use change
# 147     Afghanistan   Emissions on agricultural land
# 148     Afghanistan   Emissions on agricultural land
# 149     Afghanistan   Emissions on agricultural land
# 150     Afghanistan   Emissions on agricultural land
# 151     Afghanistan   Emissions on agricultural land
# 152     Afghanistan   Emissions on agricultural land
# 153     Afghanistan        Pre- and post- production
# 154     Afghanistan        Pre- and post- production
# 155     Afghanistan        Pre- and post- production
# 156     Afghanistan        Pre- and post- production
# 157     Afghanistan        Pre- and post- production
# 158     Afghanistan        Pre- and post- production
# 159     Afghanistan                Agri-food systems
# 160     Afghanistan                Agri-food systems
# 161     Afghanistan                Agri-food systems
# 162     Afghanistan                Agri-food systems
# 163     Afghanistan                Agri-food systems
# 164     Afghanistan                Agri-food systems
# 165     Afghanistan                 IPCC Agriculture
# 166     Afghanistan                 IPCC Agriculture
# 167     Afghanistan                 IPCC Agriculture
# 168     Afghanistan                 IPCC Agriculture
# 169     Afghanistan                 IPCC Agriculture
# 170     Afghanistan                 IPCC Agriculture
# 171     Afghanistan                 IPCC Agriculture
# 172     Afghanistan               Agricultural Soils
# 173     Afghanistan               Agricultural Soils
# 174     Afghanistan               Agricultural Soils
# 175     Afghanistan               Agricultural Soils
# 176     Afghanistan               Agricultural Soils
# 177     Afghanistan                           LULUCF
# 178     Afghanistan                           LULUCF
# 179     Afghanistan                           LULUCF
# 180     Afghanistan                           LULUCF
# 181     Afghanistan                           LULUCF
# 182     Afghanistan                           LULUCF
# 183     Afghanistan                            AFOLU
# 184     Afghanistan                            AFOLU
# 185     Afghanistan                            AFOLU
# 186     Afghanistan                            AFOLU
# 187     Afghanistan                            AFOLU
# 188     Afghanistan                            AFOLU
# 189     Afghanistan          All sectors with LULUCF
# 190     Afghanistan          All sectors with LULUCF
# 191     Afghanistan          All sectors with LULUCF
# 192     Afghanistan          All sectors with LULUCF
# 193     Afghanistan          All sectors with LULUCF
# 194     Afghanistan          All sectors with LULUCF
# 195     Afghanistan       All sectors without LULUCF
# 196     Afghanistan       All sectors without LULUCF
# 197     Afghanistan       All sectors without LULUCF
# 198     Afghanistan       All sectors without LULUCF
# 199     Afghanistan       All sectors without LULUCF
# 200     Afghanistan       All sectors without LULUCF
# 52690   Afghanistan                    Crop Residues
# 52691   Afghanistan                    Crop Residues
# 52692   Afghanistan                    Crop Residues
# 52693   Afghanistan                    Crop Residues
# 52694   Afghanistan                    Crop Residues
# 52695   Afghanistan                 Rice Cultivation
# 52696   Afghanistan                 Rice Cultivation
# 52697   Afghanistan                 Rice Cultivation
# 52698   Afghanistan          Burning - Crop residues
# 52699   Afghanistan          Burning - Crop residues
# 52700   Afghanistan          Burning - Crop residues
# 52701   Afghanistan          Burning - Crop residues
# 52702   Afghanistan          Burning - Crop residues
# 52703   Afghanistan             Enteric Fermentation
# 52704   Afghanistan             Enteric Fermentation
# 52705   Afghanistan             Enteric Fermentation
# 52706   Afghanistan                Manure Management
# 52707   Afghanistan                Manure Management
# 52708   Afghanistan                Manure Management
# 52709   Afghanistan                Manure Management
# 52710   Afghanistan                Manure Management
# 52711   Afghanistan           Manure left on Pasture
# 52712   Afghanistan           Manure left on Pasture
# 52713   Afghanistan           Manure left on Pasture
# 52714   Afghanistan           Manure left on Pasture
# 52715   Afghanistan           Manure left on Pasture
# 52716   Afghanistan          Manure applied to Soils
# 52717   Afghanistan          Manure applied to Soils
# 52718   Afghanistan          Manure applied to Soils
# 52719   Afghanistan          Manure applied to Soils
# 52720   Afghanistan          Manure applied to Soils
# 52721   Afghanistan            Synthetic Fertilizers
# 52722   Afghanistan            Synthetic Fertilizers
# 52723   Afghanistan            Synthetic Fertilizers
# 52724   Afghanistan            Synthetic Fertilizers
# 52725   Afghanistan            Synthetic Fertilizers
# 52726   Afghanistan            Drained organic soils
# 52727   Afghanistan      Drained organic soils (CO2)
# 52728   Afghanistan      Drained organic soils (CO2)
# 52729   Afghanistan      Drained organic soils (N2O)
# 52730   Afghanistan      Drained organic soils (N2O)
# 52731   Afghanistan      Drained organic soils (N2O)
# 52732   Afghanistan               On-farm energy use
# 52733   Afghanistan               On-farm energy use
# 52734   Afghanistan               On-farm energy use
# 52735   Afghanistan               On-farm energy use
# 52736   Afghanistan               On-farm energy use
# 52737   Afghanistan               On-farm energy use
# 52738   Afghanistan                       Forestland
# 52739   Afghanistan                       Forestland
# 52740   Afghanistan            Net Forest conversion
# 52741   Afghanistan            Net Forest conversion
# 52742   Afghanistan                    Savanna fires
# 52743   Afghanistan                    Savanna fires
# 52744   Afghanistan                    Savanna fires
# 52745   Afghanistan                    Savanna fires
# 52746   Afghanistan                    Savanna fires
# 52747   Afghanistan           Fires in organic soils
# 52748   Afghanistan           Fires in organic soils
# 52749   Afghanistan           Fires in organic soils
# 52750   Afghanistan           Fires in organic soils
# 52751   Afghanistan                     Forest fires
# 52752   Afghanistan                     Forest fires
# 52753   Afghanistan                     Forest fires
# 52754   Afghanistan                     Forest fires
# 52755   Afghanistan                     Forest fires
# 52756   Afghanistan  Fires in humid tropical forests
# 52757   Afghanistan  Fires in humid tropical forests
# 52758   Afghanistan  Fires in humid tropical forests
# 52759   Afghanistan  Fires in humid tropical forests
# 52760   Afghanistan  Fires in humid tropical forests
# 52761   Afghanistan        Waste - agri-food systems
# 52762   Afghanistan        Waste - agri-food systems
# 52763   Afghanistan        Waste - agri-food systems
# 52764   Afghanistan        Waste - agri-food systems
# 52765   Afghanistan        Waste - agri-food systems
# 52766   Afghanistan        Waste - agri-food systems
# 52767   Afghanistan        Fertilizers Manufacturing
# 52768   Afghanistan        Fertilizers Manufacturing
# 52769   Afghanistan          On-farm electricity use
# 52770   Afghanistan          On-farm electricity use
# 52771   Afghanistan          On-farm electricity use
# 52772   Afghanistan          On-farm electricity use
# 52773   Afghanistan          On-farm electricity use
# 52774   Afghanistan          On-farm electricity use
# 52775   Afghanistan                  Food Processing
# 52776   Afghanistan                  Food Processing
# 52777   Afghanistan                  Food Processing
# 52778   Afghanistan                  Food Processing
# 52779   Afghanistan                  Food Processing
# 52780   Afghanistan                  Food Processing
# 52781   Afghanistan                   Food Packaging
# 52782   Afghanistan                   Food Packaging
# 52783   Afghanistan                   Food Packaging
# 52784   Afghanistan                   Food Packaging
# 52785   Afghanistan                   Food Packaging
# 52786   Afghanistan                   Food Packaging
# 52787   Afghanistan                      Food Retail
# 52788   Afghanistan                      Food Retail
# 52789   Afghanistan                      Food Retail
# 52790   Afghanistan                      Food Retail
# 52791   Afghanistan                      Food Retail
# 52792   Afghanistan                      Food Retail
# 52793   Afghanistan       Food Household Consumption
# 52794   Afghanistan       Food Household Consumption
# 52795   Afghanistan       Food Household Consumption
# 52796   Afghanistan       Food Household Consumption
# 52797   Afghanistan       Food Household Consumption
# 52798   Afghanistan       Food Household Consumption
# 52799   Afghanistan                   Food Transport
# 52800   Afghanistan                   Food Transport
# 52801   Afghanistan                   Food Transport
# 52802   Afghanistan                   Food Transport
# 52803   Afghanistan                   Food Transport
# 52804   Afghanistan                   Food Transport
# 52805   Afghanistan                           Energy
# 52806   Afghanistan                           Energy
# 52807   Afghanistan                           Energy
# 52808   Afghanistan                           Energy
# 52809   Afghanistan                           Energy
# 52810   Afghanistan                           Energy
# 52811   Afghanistan                             IPPU
# 52812   Afghanistan                             IPPU
# 52813   Afghanistan                             IPPU
# 52814   Afghanistan                             IPPU
# 52815   Afghanistan                            Waste
# 52816   Afghanistan                            Waste
# 52817   Afghanistan                            Waste
# 52818   Afghanistan                            Waste
# 52819   Afghanistan                            Waste
# 52820   Afghanistan                            Other
# 52821   Afghanistan                            Other
# 52822   Afghanistan                            Other
# 52823   Afghanistan              Farm-gate emissions
# 52824   Afghanistan              Farm-gate emissions
# 52825   Afghanistan              Farm-gate emissions
# 52826   Afghanistan              Farm-gate emissions
# 52827   Afghanistan              Farm-gate emissions
# 52828   Afghanistan              Farm-gate emissions
# 52829   Afghanistan              Farm-gate emissions
# 52830   Afghanistan              Farm-gate emissions
# 52831   Afghanistan                  Land Use change
# 52832   Afghanistan                  Land Use change
# 52833   Afghanistan                  Land Use change
# 52834   Afghanistan                  Land Use change
# 52835   Afghanistan                  Land Use change
# 52836   Afghanistan                  Land Use change
# 52837   Afghanistan   Emissions on agricultural land
# 52838   Afghanistan   Emissions on agricultural land
# 52839   Afghanistan   Emissions on agricultural land
# 52840   Afghanistan   Emissions on agricultural land
# 52841   Afghanistan   Emissions on agricultural land
# 52842   Afghanistan   Emissions on agricultural land
# 52843   Afghanistan        Pre- and post- production
# 52844   Afghanistan        Pre- and post- production
# 52845   Afghanistan        Pre- and post- production
# 52846   Afghanistan        Pre- and post- production
# 52847   Afghanistan        Pre- and post- production
# 52848   Afghanistan        Pre- and post- production
# 52849   Afghanistan                Agri-food systems
# 52850   Afghanistan                Agri-food systems
# 52851   Afghanistan                Agri-food systems
# 52852   Afghanistan                Agri-food systems
# 52853   Afghanistan                Agri-food systems
# 52854   Afghanistan                Agri-food systems
# 52855   Afghanistan                 IPCC Agriculture
# 52856   Afghanistan                 IPCC Agriculture
# 52857   Afghanistan                 IPCC Agriculture
# 52858   Afghanistan                 IPCC Agriculture
# 52859   Afghanistan                 IPCC Agriculture
# 52860   Afghanistan                 IPCC Agriculture
# 52861   Afghanistan                 IPCC Agriculture
# 52862   Afghanistan               Agricultural Soils
# 52863   Afghanistan               Agricultural Soils
# 52864   Afghanistan               Agricultural Soils
# 52865   Afghanistan               Agricultural Soils
# 52866   Afghanistan               Agricultural Soils
# 52867   Afghanistan                           LULUCF
# 52868   Afghanistan                           LULUCF
# 52869   Afghanistan                           LULUCF
# 52870   Afghanistan                           LULUCF
# 52871   Afghanistan                           LULUCF
# 52872   Afghanistan                           LULUCF
# 52873   Afghanistan                            AFOLU
# 52874   Afghanistan                            AFOLU
# 52875   Afghanistan                            AFOLU
# 52876   Afghanistan                            AFOLU
# 52877   Afghanistan                            AFOLU
# 52878   Afghanistan                            AFOLU
# 52879   Afghanistan          All sectors with LULUCF
# 52880   Afghanistan          All sectors with LULUCF
# 52881   Afghanistan          All sectors with LULUCF
# 52882   Afghanistan          All sectors with LULUCF
# 52883   Afghanistan          All sectors with LULUCF
# 52884   Afghanistan          All sectors with LULUCF
# 52885   Afghanistan       All sectors without LULUCF
# 52886   Afghanistan       All sectors without LULUCF
# 52887   Afghanistan       All sectors without LULUCF
# 52888   Afghanistan       All sectors without LULUCF
# 52889   Afghanistan       All sectors without LULUCF
# 52890   Afghanistan       All sectors without LULUCF
# 105380  Afghanistan                    Crop Residues
# 105381  Afghanistan                    Crop Residues
# 105382  Afghanistan                    Crop Residues
# 105383  Afghanistan                    Crop Residues
# 105384  Afghanistan                    Crop Residues
# 105385  Afghanistan                 Rice Cultivation
# 105386  Afghanistan                 Rice Cultivation
# 105387  Afghanistan                 Rice Cultivation
# 105388  Afghanistan          Burning - Crop residues
# 105389  Afghanistan          Burning - Crop residues
# 105390  Afghanistan          Burning - Crop residues
# 105391  Afghanistan          Burning - Crop residues
# 105392  Afghanistan          Burning - Crop residues
# 105393  Afghanistan             Enteric Fermentation
# 105394  Afghanistan             Enteric Fermentation
# 105395  Afghanistan             Enteric Fermentation
# 105396  Afghanistan                Manure Management
# 105397  Afghanistan                Manure Management
# 105398  Afghanistan                Manure Management
# 105399  Afghanistan                Manure Management
# 105400  Afghanistan                Manure Management
# 105401  Afghanistan           Manure left on Pasture
# 105402  Afghanistan           Manure left on Pasture
# 105403  Afghanistan           Manure left on Pasture
# 105404  Afghanistan           Manure left on Pasture
# 105405  Afghanistan           Manure left on Pasture
# 105406  Afghanistan          Manure applied to Soils
# 105407  Afghanistan          Manure applied to Soils
# 105408  Afghanistan          Manure applied to Soils
# 105409  Afghanistan          Manure applied to Soils
# 105410  Afghanistan          Manure applied to Soils
# 105411  Afghanistan            Synthetic Fertilizers
# 105412  Afghanistan            Synthetic Fertilizers
# 105413  Afghanistan            Synthetic Fertilizers
# 105414  Afghanistan            Synthetic Fertilizers
# 105415  Afghanistan            Synthetic Fertilizers
# 105416  Afghanistan            Drained organic soils
# 105417  Afghanistan      Drained organic soils (CO2)
# 105418  Afghanistan      Drained organic soils (CO2)
# 105419  Afghanistan      Drained organic soils (N2O)
# 105420  Afghanistan      Drained organic soils (N2O)
# 105421  Afghanistan      Drained organic soils (N2O)
# 105422  Afghanistan               On-farm energy use
# 105423  Afghanistan               On-farm energy use
# 105424  Afghanistan               On-farm energy use
# 105425  Afghanistan               On-farm energy use
# 105426  Afghanistan               On-farm energy use
# 105427  Afghanistan               On-farm energy use
# 105428  Afghanistan                       Forestland
# 105429  Afghanistan                       Forestland
# 105430  Afghanistan            Net Forest conversion
# 105431  Afghanistan            Net Forest conversion
# 105432  Afghanistan                    Savanna fires
# 105433  Afghanistan                    Savanna fires
# 105434  Afghanistan                    Savanna fires
# 105435  Afghanistan                    Savanna fires
# 105436  Afghanistan                    Savanna fires
# 105437  Afghanistan           Fires in organic soils
# 105438  Afghanistan           Fires in organic soils
# 105439  Afghanistan           Fires in organic soils
# 105440  Afghanistan           Fires in organic soils
# 105441  Afghanistan                     Forest fires
# 105442  Afghanistan                     Forest fires
# 105443  Afghanistan                     Forest fires
# 105444  Afghanistan                     Forest fires
# 105445  Afghanistan                     Forest fires
# 105446  Afghanistan  Fires in humid tropical forests
# 105447  Afghanistan  Fires in humid tropical forests
# 105448  Afghanistan  Fires in humid tropical forests
# 105449  Afghanistan  Fires in humid tropical forests
# 105450  Afghanistan  Fires in humid tropical forests
# 105451  Afghanistan        Waste - agri-food systems
# 105452  Afghanistan        Waste - agri-food systems
# 105453  Afghanistan        Waste - agri-food systems
# 105454  Afghanistan        Waste - agri-food systems
# 105455  Afghanistan        Waste - agri-food systems
# 105456  Afghanistan        Waste - agri-food systems
# 105457  Afghanistan        Fertilizers Manufacturing
# 105458  Afghanistan        Fertilizers Manufacturing
# 105459  Afghanistan          On-farm electricity use
# 105460  Afghanistan          On-farm electricity use
# 105461  Afghanistan          On-farm electricity use
# 105462  Afghanistan          On-farm electricity use
# 105463  Afghanistan          On-farm electricity use
# 105464  Afghanistan          On-farm electricity use
# 105465  Afghanistan                  Food Processing
# 105466  Afghanistan                  Food Processing
# 105467  Afghanistan                  Food Processing
# 105468  Afghanistan                  Food Processing
# 105469  Afghanistan                  Food Processing
# 105470  Afghanistan                  Food Processing
# 105471  Afghanistan                   Food Packaging
# 105472  Afghanistan                   Food Packaging
# 105473  Afghanistan                   Food Packaging
# 105474  Afghanistan                   Food Packaging
# 105475  Afghanistan                   Food Packaging
# 105476  Afghanistan                   Food Packaging
# 105477  Afghanistan                      Food Retail
#
#                                  Element  Year  Total_Emissions_KT
# 0                 Direct emissions (N2O)  2000              0.5200
# 1               Indirect emissions (N2O)  2000              0.1170
# 2                        Emissions (N2O)  2000              0.6370
# 3       Emissions (CO2eq) from N2O (AR5)  2000            168.8070
# 4                Emissions (CO2eq) (AR5)  2000            168.8070
# 5                        Emissions (CH4)  2000             18.2000
# 6       Emissions (CO2eq) from CH4 (AR5)  2000            509.6000
# 7                Emissions (CO2eq) (AR5)  2000            509.6000
# 8                        Emissions (CH4)  2000              2.6471
# 9                        Emissions (N2O)  2000              0.0686
# 10      Emissions (CO2eq) from CH4 (AR5)  2000             74.1182
# 11      Emissions (CO2eq) from N2O (AR5)  2000             18.1864
# 12               Emissions (CO2eq) (AR5)  2000             92.3047
# 13                       Emissions (CH4)  2000            272.1400
# 14      Emissions (CO2eq) from CH4 (AR5)  2000           7619.9200
# 15               Emissions (CO2eq) (AR5)  2000           7619.9200
# 16                       Emissions (CH4)  2000             15.0621
# 17                       Emissions (N2O)  2000              0.3613
# 18      Emissions (CO2eq) from CH4 (AR5)  2000            421.7377
# 19      Emissions (CO2eq) from N2O (AR5)  2000             95.7551
# 20               Emissions (CO2eq) (AR5)  2000            517.4928
# 21                Direct emissions (N2O)  2000              6.2178
# 22              Indirect emissions (N2O)  2000              2.2615
# 23                       Emissions (N2O)  2000              8.4794
# 24      Emissions (CO2eq) from N2O (AR5)  2000           2247.0318
# 25               Emissions (CO2eq) (AR5)  2000           2247.0318
# 26                Direct emissions (N2O)  2000              0.9093
# 27              Indirect emissions (N2O)  2000              0.3865
# 28                       Emissions (N2O)  2000              1.2958
# 29      Emissions (CO2eq) from N2O (AR5)  2000            343.3925
# 30               Emissions (CO2eq) (AR5)  2000            343.3925
# 31                Direct emissions (N2O)  2000              0.0786
# 32              Indirect emissions (N2O)  2000              0.0255
# 33                       Emissions (N2O)  2000              0.1041
# 34      Emissions (CO2eq) from N2O (AR5)  2000             27.5884
# 35               Emissions (CO2eq) (AR5)  2000             27.5884
# 36               Emissions (CO2eq) (AR5)  2000              0.0000
# 37                       Emissions (CO2)  2000              0.0000
# 38               Emissions (CO2eq) (AR5)  2000              0.0000
# 39                       Emissions (N2O)  2000              0.0000
# 40      Emissions (CO2eq) from N2O (AR5)  2000              0.0000
# 41               Emissions (CO2eq) (AR5)  2000              0.0000
# 42                       Emissions (CH4)  2000              0.0021
# 43                       Emissions (N2O)  2000              0.0079
# 44                       Emissions (CO2)  2000             25.0585
# 45      Emissions (CO2eq) from CH4 (AR5)  2000              0.0594
# 46      Emissions (CO2eq) from N2O (AR5)  2000              2.0975
# 47               Emissions (CO2eq) (AR5)  2000             27.2153
# 48                       Emissions (CO2)  2000          -2388.8030
# 49               Emissions (CO2eq) (AR5)  2000          -2388.8030
# 50                       Emissions (CO2)  2000              0.0000
# 51               Emissions (CO2eq) (AR5)  2000              0.0000
# 52                       Emissions (CH4)  2000              0.4365
# 53                       Emissions (N2O)  2000              0.0398
# 54      Emissions (CO2eq) from CH4 (AR5)  2000             12.2208
# 55      Emissions (CO2eq) from N2O (AR5)  2000             10.5602
# 56               Emissions (CO2eq) (AR5)  2000             22.7810
# 57                       Emissions (CH4)  2000              0.0000
# 58                       Emissions (CO2)  2000              0.0000
# 59      Emissions (CO2eq) from CH4 (AR5)  2000              0.0000
# 60               Emissions (CO2eq) (AR5)  2000              0.0000
# 61                       Emissions (CH4)  2000              0.0167
# 62                       Emissions (N2O)  2000              0.0009
# 63      Emissions (CO2eq) from CH4 (AR5)  2000              0.4668
# 64      Emissions (CO2eq) from N2O (AR5)  2000              0.2443
# 65               Emissions (CO2eq) (AR5)  2000              0.7111
# 66                       Emissions (CH4)  2000              0.0000
# 67                       Emissions (N2O)  2000              0.0000
# 68      Emissions (CO2eq) from CH4 (AR5)  2000              0.0000
# 69      Emissions (CO2eq) from N2O (AR5)  2000              0.0000
# 70               Emissions (CO2eq) (AR5)  2000              0.0000
# 71                       Emissions (CH4)  2000             29.9460
# 72                       Emissions (N2O)  2000              0.3727
# 73                       Emissions (CO2)  2000              0.0000
# 74      Emissions (CO2eq) from CH4 (AR5)  2000            838.4871
# 75      Emissions (CO2eq) from N2O (AR5)  2000             98.7604
# 76               Emissions (CO2eq) (AR5)  2000            937.2475
# 77                       Emissions (CO2)  2000             35.7872
# 78               Emissions (CO2eq) (AR5)  2000             35.7872
# 79                       Emissions (CH4)  2000              0.0120
# 80                       Emissions (N2O)  2000              0.0001
# 81                       Emissions (CO2)  2000              2.7774
# 82      Emissions (CO2eq) from CH4 (AR5)  2000              0.3360
# 83      Emissions (CO2eq) from N2O (AR5)  2000              0.0265
# 84               Emissions (CO2eq) (AR5)  2000              3.1399
# 85                       Emissions (CH4)  2000              0.9714
# 86                       Emissions (N2O)  2000              0.0005
# 87                       Emissions (CO2)  2000             10.5259
# 88      Emissions (CO2eq) from CH4 (AR5)  2000             27.1992
# 89      Emissions (CO2eq) from N2O (AR5)  2000              0.1325
# 90               Emissions (CO2eq) (AR5)  2000             37.8576
# 91                       Emissions (CH4)  2000              0.0006
# 92                       Emissions (N2O)  2000              0.0000
# 93                       Emissions (CO2)  2000              1.5922
# 94      Emissions (CO2eq) from CH4 (AR5)  2000              0.0168
# 95      Emissions (CO2eq) from N2O (AR5)  2000              0.0000
# 96               Emissions (CO2eq) (AR5)  2000              1.6090
# 97                       Emissions (CH4)  2000              0.0045
# 98                       Emissions (N2O)  2000              0.0000
# 99                       Emissions (CO2)  2000              1.0471
# 100     Emissions (CO2eq) from CH4 (AR5)  2000              0.1260
# 101     Emissions (CO2eq) from N2O (AR5)  2000              0.0000
# 102              Emissions (CO2eq) (AR5)  2000              1.1731
# 103                      Emissions (CH4)  2000              0.0511
# 104                      Emissions (N2O)  2000              0.0004
# 105                      Emissions (CO2)  2000             12.0750
# 106     Emissions (CO2eq) from CH4 (AR5)  2000              1.4308
# 107     Emissions (CO2eq) from N2O (AR5)  2000              0.1060
# 108              Emissions (CO2eq) (AR5)  2000             13.6118
# 109                      Emissions (CH4)  2000              0.0072
# 110                      Emissions (N2O)  2000              0.0003
# 111                      Emissions (CO2)  2000             13.7445
# 112     Emissions (CO2eq) from CH4 (AR5)  2000              0.2016
# 113     Emissions (CO2eq) from N2O (AR5)  2000              0.0795
# 114              Emissions (CO2eq) (AR5)  2000             14.0256
# 115                      Emissions (CH4)  2000             13.7000
# 116                      Emissions (N2O)  2000              0.0743
# 117                      Emissions (CO2)  2000            751.0000
# 118     Emissions (CO2eq) from CH4 (AR5)  2000            383.6000
# 119     Emissions (CO2eq) from N2O (AR5)  2000             19.6895
# 120              Emissions (CO2eq) (AR5)  2000           1154.2895
# 121                      Emissions (N2O)  2000              0.0061
# 122                      Emissions (CO2)  2000            163.0000
# 123     Emissions (CO2eq) from N2O (AR5)  2000              1.6033
# 124              Emissions (CO2eq) (AR5)  2000            164.6033
# 125                      Emissions (CH4)  2000             96.9000
# 126                      Emissions (N2O)  2000              0.5210
# 127     Emissions (CO2eq) from CH4 (AR5)  2000           2713.2000
# 128     Emissions (CO2eq) from N2O (AR5)  2000            138.0650
# 129              Emissions (CO2eq) (AR5)  2000           2851.2650
# 130                      Emissions (N2O)  2000              0.0578
# 131     Emissions (CO2eq) from N2O (AR5)  2000             15.3170
# 132              Emissions (CO2eq) (AR5)  2000             15.3170
# 133                      Emissions (CH4)  2000            308.4877
# 134               Direct emissions (N2O)  2000              7.7258
# 135             Indirect emissions (N2O)  2000              2.7905
# 136                      Emissions (N2O)  2000             10.9940
# 137                      Emissions (CO2)  2000             25.0585
# 138     Emissions (CO2eq) from CH4 (AR5)  2000           8637.6561
# 139     Emissions (CO2eq) from N2O (AR5)  2000           2913.4190
# 140              Emissions (CO2eq) (AR5)  2000          11576.1335
# 141                      Emissions (CH4)  2000              0.0000
# 142                      Emissions (N2O)  2000              0.0000
# 143                      Emissions (CO2)  2000              0.0000
# 144     Emissions (CO2eq) from CH4 (AR5)  2000              0.0000
# 145     Emissions (CO2eq) from N2O (AR5)  2000              0.0000
# 146              Emissions (CO2eq) (AR5)  2000              0.0000
# 147                      Emissions (CH4)  2000            308.4877
# 148                      Emissions (N2O)  2000             10.9940
# 149                      Emissions (CO2)  2000             25.0585
# 150     Emissions (CO2eq) from CH4 (AR5)  2000           8637.6561
# 151     Emissions (CO2eq) from N2O (AR5)  2000           2913.4190
# 152              Emissions (CO2eq) (AR5)  2000          11576.1335
# 153                      Emissions (CH4)  2000             30.9928
# 154                      Emissions (N2O)  2000              0.3740
# 155                      Emissions (CO2)  2000             77.5493
# 156     Emissions (CO2eq) from CH4 (AR5)  2000            867.7975
# 157     Emissions (CO2eq) from N2O (AR5)  2000             99.1049
# 158              Emissions (CO2eq) (AR5)  2000           1044.4517
# 159                      Emissions (CH4)  2000            339.4805
# 160                      Emissions (N2O)  2000             11.3680
# 161                      Emissions (CO2)  2000            102.6078
# 162     Emissions (CO2eq) from CH4 (AR5)  2000           9505.4536
# 163     Emissions (CO2eq) from N2O (AR5)  2000           3012.5239
# 164              Emissions (CO2eq) (AR5)  2000          12620.5852
# 165                      Emissions (CH4)  2000            308.4856
# 166               Direct emissions (N2O)  2000              7.7258
# 167             Indirect emissions (N2O)  2000              2.7905
# 168                      Emissions (N2O)  2000             10.9861
# 169     Emissions (CO2eq) from CH4 (AR5)  2000           8637.5967
# 170     Emissions (CO2eq) from N2O (AR5)  2000           2911.3215
# 171              Emissions (CO2eq) (AR5)  2000          11548.9182
# 172               Direct emissions (N2O)  2000              7.7258
# 173             Indirect emissions (N2O)  2000              2.7905
# 174                      Emissions (N2O)  2000             10.5163
# 175     Emissions (CO2eq) from N2O (AR5)  2000           2786.8197
# 176              Emissions (CO2eq) (AR5)  2000           2786.8197
# 177                      Emissions (CH4)  2000              0.0167
# 178                      Emissions (N2O)  2000              0.0009
# 179                      Emissions (CO2)  2000          -2388.8030
# 180     Emissions (CO2eq) from CH4 (AR5)  2000              0.4668
# 181     Emissions (CO2eq) from N2O (AR5)  2000              0.2443
# 182              Emissions (CO2eq) (AR5)  2000          -2388.0919
# 183                      Emissions (CH4)  2000            308.5023
# 184                      Emissions (N2O)  2000             10.9870
# 185                      Emissions (CO2)  2000          -2388.8030
# 186     Emissions (CO2eq) from CH4 (AR5)  2000           8638.0635
# 187     Emissions (CO2eq) from N2O (AR5)  2000           2911.5658
# 188              Emissions (CO2eq) (AR5)  2000           9160.8263
# 189                      Emissions (CH4)  2000            419.1023
# 190                      Emissions (N2O)  2000             11.6462
# 191                      Emissions (CO2)  2000          -1474.8030
# 192     Emissions (CO2eq) from CH4 (AR5)  2000          11734.8635
# 193     Emissions (CO2eq) from N2O (AR5)  2000           3086.2405
# 194              Emissions (CO2eq) (AR5)  2000          13346.3010
# 195                      Emissions (CH4)  2000            419.0856
# 196                      Emissions (N2O)  2000             11.6453
# 197                      Emissions (CO2)  2000            914.0000
# 198     Emissions (CO2eq) from CH4 (AR5)  2000          11734.3967
# 199     Emissions (CO2eq) from N2O (AR5)  2000           3085.9962
# 200              Emissions (CO2eq) (AR5)  2000          15734.3929
# 52690             Direct emissions (N2O)  2001              0.5267
# 52691           Indirect emissions (N2O)  2001              0.1185
# 52692                    Emissions (N2O)  2001              0.6452
# 52693   Emissions (CO2eq) from N2O (AR5)  2001            170.9884
# 52694            Emissions (CO2eq) (AR5)  2001            170.9884
# 52695                    Emissions (CH4)  2001             16.9400
# 52696   Emissions (CO2eq) from CH4 (AR5)  2001            474.3200
# 52697            Emissions (CO2eq) (AR5)  2001            474.3200
# 52698                    Emissions (CH4)  2001              2.3205
# 52699                    Emissions (N2O)  2001              0.0602
# 52700   Emissions (CO2eq) from CH4 (AR5)  2001             64.9744
# 52701   Emissions (CO2eq) from N2O (AR5)  2001             15.9428
# 52702            Emissions (CO2eq) (AR5)  2001             80.9172
# 52703                    Emissions (CH4)  2001            225.4030
# 52704   Emissions (CO2eq) from CH4 (AR5)  2001           6311.2840
# 52705            Emissions (CO2eq) (AR5)  2001           6311.2840
# 52706                    Emissions (CH4)  2001             12.1998
# 52707                    Emissions (N2O)  2001              0.3193
# 52708   Emissions (CO2eq) from CH4 (AR5)  2001            341.5936
# 52709   Emissions (CO2eq) from N2O (AR5)  2001             84.6123
# 52710            Emissions (CO2eq) (AR5)  2001            426.2058
# 52711             Direct emissions (N2O)  2001              5.1754
# 52712           Indirect emissions (N2O)  2001              1.8957
# 52713                    Emissions (N2O)  2001              7.0711
# 52714   Emissions (CO2eq) from N2O (AR5)  2001           1873.8501
# 52715            Emissions (CO2eq) (AR5)  2001           1873.8501
# 52716             Direct emissions (N2O)  2001              0.7871
# 52717           Indirect emissions (N2O)  2001              0.3345
# 52718                    Emissions (N2O)  2001              1.1216
# 52719   Emissions (CO2eq) from N2O (AR5)  2001            297.2256
# 52720            Emissions (CO2eq) (AR5)  2001            297.2256
# 52721             Direct emissions (N2O)  2001              0.2891
# 52722           Indirect emissions (N2O)  2001              0.0940
# 52723                    Emissions (N2O)  2001              0.3831
# 52724   Emissions (CO2eq) from N2O (AR5)  2001            101.5253
# 52725            Emissions (CO2eq) (AR5)  2001            101.5253
# 52726            Emissions (CO2eq) (AR5)  2001              0.0000
# 52727                    Emissions (CO2)  2001              0.0000
# 52728            Emissions (CO2eq) (AR5)  2001              0.0000
# 52729                    Emissions (N2O)  2001              0.0000
# 52730   Emissions (CO2eq) from N2O (AR5)  2001              0.0000
# 52731            Emissions (CO2eq) (AR5)  2001              0.0000
# 52732                    Emissions (CH4)  2001              0.0046
# 52733                    Emissions (N2O)  2001              0.0091
# 52734                    Emissions (CO2)  2001             28.5361
# 52735   Emissions (CO2eq) from CH4 (AR5)  2001              0.1275
# 52736   Emissions (CO2eq) from N2O (AR5)  2001              2.4132
# 52737            Emissions (CO2eq) (AR5)  2001             31.0767
# 52738                    Emissions (CO2)  2001            121.9016
# 52739            Emissions (CO2eq) (AR5)  2001            121.9016
# 52740                    Emissions (CO2)  2001              0.0000
# 52741            Emissions (CO2eq) (AR5)  2001              0.0000
# 52742                    Emissions (CH4)  2001              0.0043
# 52743                    Emissions (N2O)  2001              0.0004
# 52744   Emissions (CO2eq) from CH4 (AR5)  2001              0.1190
# 52745   Emissions (CO2eq) from N2O (AR5)  2001              0.1029
# 52746            Emissions (CO2eq) (AR5)  2001              0.2219
# 52747                    Emissions (CH4)  2001              0.0000
# 52748                    Emissions (CO2)  2001              0.0000
# 52749   Emissions (CO2eq) from CH4 (AR5)  2001              0.0000
# 52750            Emissions (CO2eq) (AR5)  2001              0.0000
# 52751                    Emissions (CH4)  2001              0.0000
# 52752                    Emissions (N2O)  2001              0.0000
# 52753   Emissions (CO2eq) from CH4 (AR5)  2001              0.0000
# 52754   Emissions (CO2eq) from N2O (AR5)  2001              0.0000
# 52755            Emissions (CO2eq) (AR5)  2001              0.0000
# 52756                    Emissions (CH4)  2001              0.0000
# 52757                    Emissions (N2O)  2001              0.0000
# 52758   Emissions (CO2eq) from CH4 (AR5)  2001              0.0000
# 52759   Emissions (CO2eq) from N2O (AR5)  2001              0.0000
# 52760            Emissions (CO2eq) (AR5)  2001              0.0000
# 52761                    Emissions (CH4)  2001             30.8044
# 52762                    Emissions (N2O)  2001              0.3661
# 52763                    Emissions (CO2)  2001              0.0000
# 52764   Emissions (CO2eq) from CH4 (AR5)  2001            862.5230
# 52765   Emissions (CO2eq) from N2O (AR5)  2001             97.0262
# 52766            Emissions (CO2eq) (AR5)  2001            959.5492
# 52767                    Emissions (CO2)  2001             35.4204
# 52768            Emissions (CO2eq) (AR5)  2001             35.4204
# 52769                    Emissions (CH4)  2001              0.0120
# 52770                    Emissions (N2O)  2001              0.0001
# 52771                    Emissions (CO2)  2001              3.2371
# 52772   Emissions (CO2eq) from CH4 (AR5)  2001              0.3360
# 52773   Emissions (CO2eq) from N2O (AR5)  2001              0.0265
# 52774            Emissions (CO2eq) (AR5)  2001              3.5996
# 52775                    Emissions (CH4)  2001              0.9635
# 52776                    Emissions (N2O)  2001              0.0005
# 52777                    Emissions (CO2)  2001             11.2120
# 52778   Emissions (CO2eq) from CH4 (AR5)  2001             26.9780
# 52779   Emissions (CO2eq) from N2O (AR5)  2001              0.1325
# 52780            Emissions (CO2eq) (AR5)  2001             38.3225
# 52781                    Emissions (CH4)  2001              0.0005
# 52782                    Emissions (N2O)  2001              0.0000
# 52783                    Emissions (CO2)  2001              1.4973
# 52784   Emissions (CO2eq) from CH4 (AR5)  2001              0.0140
# 52785   Emissions (CO2eq) from N2O (AR5)  2001              0.0000
# 52786            Emissions (CO2eq) (AR5)  2001              1.5113
# 52787                    Emissions (CH4)  2001              0.0045
# 52788                    Emissions (N2O)  2001              0.0000
# 52789                    Emissions (CO2)  2001              1.2204
# 52790   Emissions (CO2eq) from CH4 (AR5)  2001              0.1260
# 52791   Emissions (CO2eq) from N2O (AR5)  2001              0.0000
# 52792            Emissions (CO2eq) (AR5)  2001              1.3464
# 52793                    Emissions (CH4)  2001              0.0500
# 52794                    Emissions (N2O)  2001              0.0004
# 52795                    Emissions (CO2)  2001             13.4863
# 52796   Emissions (CO2eq) from CH4 (AR5)  2001              1.4000
# 52797   Emissions (CO2eq) from N2O (AR5)  2001              0.1060
# 52798            Emissions (CO2eq) (AR5)  2001             14.9923
# 52799                    Emissions (CH4)  2001              0.0074
# 52800                    Emissions (N2O)  2001              0.0003
# 52801                    Emissions (CO2)  2001             12.9455
# 52802   Emissions (CO2eq) from CH4 (AR5)  2001              0.2072
# 52803   Emissions (CO2eq) from N2O (AR5)  2001              0.0795
# 52804            Emissions (CO2eq) (AR5)  2001             13.2322
# 52805                    Emissions (CH4)  2001             13.4000
# 52806                    Emissions (N2O)  2001              0.0774
# 52807                    Emissions (CO2)  2001            795.0000
# 52808   Emissions (CO2eq) from CH4 (AR5)  2001            375.2000
# 52809   Emissions (CO2eq) from N2O (AR5)  2001             20.5110
# 52810            Emissions (CO2eq) (AR5)  2001           1190.7110
# 52811                    Emissions (N2O)  2001              0.0063
# 52812                    Emissions (CO2)  2001            150.0000
# 52813   Emissions (CO2eq) from N2O (AR5)  2001              1.6748
# 52814            Emissions (CO2eq) (AR5)  2001            151.6748
# 52815                    Emissions (CH4)  2001            101.0000
# 52816                    Emissions (N2O)  2001              0.5440
# 52817   Emissions (CO2eq) from CH4 (AR5)  2001           2828.0000
# 52818   Emissions (CO2eq) from N2O (AR5)  2001            144.1600
# 52819            Emissions (CO2eq) (AR5)  2001           2972.1600
# 52820                    Emissions (N2O)  2001              0.0608
# 52821   Emissions (CO2eq) from N2O (AR5)  2001             16.1120
# 52822            Emissions (CO2eq) (AR5)  2001             16.1120
# 52823                    Emissions (CH4)  2001            256.8721
# 52824             Direct emissions (N2O)  2001              6.7784
# 52825           Indirect emissions (N2O)  2001              2.4427
# 52826                    Emissions (N2O)  2001              9.6100
# 52827                    Emissions (CO2)  2001             28.5361
# 52828   Emissions (CO2eq) from CH4 (AR5)  2001           7192.4185
# 52829   Emissions (CO2eq) from N2O (AR5)  2001           2546.6605
# 52830            Emissions (CO2eq) (AR5)  2001           9767.6150
# 52831                    Emissions (CH4)  2001              0.0000
# 52832                    Emissions (N2O)  2001              0.0000
# 52833                    Emissions (CO2)  2001              0.0000
# 52834   Emissions (CO2eq) from CH4 (AR5)  2001              0.0000
# 52835   Emissions (CO2eq) from N2O (AR5)  2001              0.0000
# 52836            Emissions (CO2eq) (AR5)  2001              0.0000
# 52837                    Emissions (CH4)  2001            256.8721
# 52838                    Emissions (N2O)  2001              9.6100
# 52839                    Emissions (CO2)  2001             28.5361
# 52840   Emissions (CO2eq) from CH4 (AR5)  2001           7192.4185
# 52841   Emissions (CO2eq) from N2O (AR5)  2001           2546.6605
# 52842            Emissions (CO2eq) (AR5)  2001           9767.6150
# 52843                    Emissions (CH4)  2001             31.8423
# 52844                    Emissions (N2O)  2001              0.3674
# 52845                    Emissions (CO2)  2001             79.0190
# 52846   Emissions (CO2eq) from CH4 (AR5)  2001            891.5842
# 52847   Emissions (CO2eq) from N2O (AR5)  2001             97.3707
# 52848            Emissions (CO2eq) (AR5)  2001           1067.9739
# 52849                    Emissions (CH4)  2001            288.7144
# 52850                    Emissions (N2O)  2001              9.9775
# 52851                    Emissions (CO2)  2001            107.5551
# 52852   Emissions (CO2eq) from CH4 (AR5)  2001           8084.0027
# 52853   Emissions (CO2eq) from N2O (AR5)  2001           2644.0311
# 52854            Emissions (CO2eq) (AR5)  2001          10835.5889
# 52855                    Emissions (CH4)  2001            256.8675
# 52856             Direct emissions (N2O)  2001              6.7784
# 52857           Indirect emissions (N2O)  2001              2.4427
# 52858                    Emissions (N2O)  2001              9.6009
# 52859   Emissions (CO2eq) from CH4 (AR5)  2001           7192.2910
# 52860   Emissions (CO2eq) from N2O (AR5)  2001           2544.2473
# 52861            Emissions (CO2eq) (AR5)  2001           9736.5383
# 52862             Direct emissions (N2O)  2001              6.7784
# 52863           Indirect emissions (N2O)  2001              2.4427
# 52864                    Emissions (N2O)  2001              9.2211
# 52865   Emissions (CO2eq) from N2O (AR5)  2001           2443.5894
# 52866            Emissions (CO2eq) (AR5)  2001           2443.5894
# 52867                    Emissions (CH4)  2001              0.0000
# 52868                    Emissions (N2O)  2001              0.0000
# 52869                    Emissions (CO2)  2001            121.9016
# 52870   Emissions (CO2eq) from CH4 (AR5)  2001              0.0000
# 52871   Emissions (CO2eq) from N2O (AR5)  2001              0.0000
# 52872            Emissions (CO2eq) (AR5)  2001            121.9016
# 52873                    Emissions (CH4)  2001            256.8675
# 52874                    Emissions (N2O)  2001              9.6009
# 52875                    Emissions (CO2)  2001            121.9016
# 52876   Emissions (CO2eq) from CH4 (AR5)  2001           7192.2910
# 52877   Emissions (CO2eq) from N2O (AR5)  2001           2544.2473
# 52878            Emissions (CO2eq) (AR5)  2001           9858.4400
# 52879                    Emissions (CH4)  2001            371.2675
# 52880                    Emissions (N2O)  2001             10.2895
# 52881                    Emissions (CO2)  2001           1066.9016
# 52882   Emissions (CO2eq) from CH4 (AR5)  2001          10395.4910
# 52883   Emissions (CO2eq) from N2O (AR5)  2001           2726.7051
# 52884            Emissions (CO2eq) (AR5)  2001          14189.0978
# 52885                    Emissions (CH4)  2001            371.2675
# 52886                    Emissions (N2O)  2001             10.2895
# 52887                    Emissions (CO2)  2001            945.0000
# 52888   Emissions (CO2eq) from CH4 (AR5)  2001          10395.4910
# 52889   Emissions (CO2eq) from N2O (AR5)  2001           2726.7051
# 52890            Emissions (CO2eq) (AR5)  2001          14067.1961
# 105380            Direct emissions (N2O)  2002              0.8200
# 105381          Indirect emissions (N2O)  2002              0.1845
# 105382                   Emissions (N2O)  2002              1.0045
# 105383  Emissions (CO2eq) from N2O (AR5)  2002            266.1975
# 105384           Emissions (CO2eq) (AR5)  2002            266.1975
# 105385                   Emissions (CH4)  2002             18.9000
# 105386  Emissions (CO2eq) from CH4 (AR5)  2002            529.2000
# 105387           Emissions (CO2eq) (AR5)  2002            529.2000
# 105388                   Emissions (CH4)  2002              2.3553
# 105389                   Emissions (N2O)  2002              0.0611
# 105390  Emissions (CO2eq) from CH4 (AR5)  2002             65.9497
# 105391  Emissions (CO2eq) from N2O (AR5)  2002             16.1821
# 105392           Emissions (CO2eq) (AR5)  2002             82.1318
# 105393                   Emissions (CH4)  2002            287.8930
# 105394  Emissions (CO2eq) from CH4 (AR5)  2002           8061.0040
# 105395           Emissions (CO2eq) (AR5)  2002           8061.0040
# 105396                   Emissions (CH4)  2002             18.3753
# 105397                   Emissions (N2O)  2002              0.2945
# 105398  Emissions (CO2eq) from CH4 (AR5)  2002            514.5073
# 105399  Emissions (CO2eq) from N2O (AR5)  2002             78.0540
# 105400           Emissions (CO2eq) (AR5)  2002            592.5613
# 105401            Direct emissions (N2O)  2002              6.0466
# 105402          Indirect emissions (N2O)  2002              2.0719
# 105403                   Emissions (N2O)  2002              8.1185
# 105404  Emissions (CO2eq) from N2O (AR5)  2002           2151.3990
# 105405           Emissions (CO2eq) (AR5)  2002           2151.3990
# 105406            Direct emissions (N2O)  2002              0.8310
# 105407          Indirect emissions (N2O)  2002              0.3532
# 105408                   Emissions (N2O)  2002              1.1842
# 105409  Emissions (CO2eq) from N2O (AR5)  2002            313.8126
# 105410           Emissions (CO2eq) (AR5)  2002            313.8126
# 105411            Direct emissions (N2O)  2002              0.3854
# 105412          Indirect emissions (N2O)  2002              0.1252
# 105413                   Emissions (N2O)  2002              0.5106
# 105414  Emissions (CO2eq) from N2O (AR5)  2002            135.3130
# 105415           Emissions (CO2eq) (AR5)  2002            135.3130
# 105416           Emissions (CO2eq) (AR5)  2002              0.0000
# 105417                   Emissions (CO2)  2002              0.0000
# 105418           Emissions (CO2eq) (AR5)  2002              0.0000
# 105419                   Emissions (N2O)  2002              0.0000
# 105420  Emissions (CO2eq) from N2O (AR5)  2002              0.0000
# 105421           Emissions (CO2eq) (AR5)  2002              0.0000
# 105422                   Emissions (CH4)  2002              0.0029
# 105423                   Emissions (N2O)  2002              0.0103
# 105424                   Emissions (CO2)  2002             37.4770
# 105425  Emissions (CO2eq) from CH4 (AR5)  2002              0.0824
# 105426  Emissions (CO2eq) from N2O (AR5)  2002              2.7356
# 105427           Emissions (CO2eq) (AR5)  2002             40.2951
# 105428                   Emissions (CO2)  2002            121.9016
# 105429           Emissions (CO2eq) (AR5)  2002            121.9016
# 105430                   Emissions (CO2)  2002              0.0000
# 105431           Emissions (CO2eq) (AR5)  2002              0.0000
# 105432                   Emissions (CH4)  2002              0.1735
# 105433                   Emissions (N2O)  2002              0.0158
# 105434  Emissions (CO2eq) from CH4 (AR5)  2002              4.8582
# 105435  Emissions (CO2eq) from N2O (AR5)  2002              4.1981
# 105436           Emissions (CO2eq) (AR5)  2002              9.0562
# 105437                   Emissions (CH4)  2002              0.0000
# 105438                   Emissions (CO2)  2002              0.0000
# 105439  Emissions (CO2eq) from CH4 (AR5)  2002              0.0000
# 105440           Emissions (CO2eq) (AR5)  2002              0.0000
# 105441                   Emissions (CH4)  2002              0.0000
# 105442                   Emissions (N2O)  2002              0.0000
# 105443  Emissions (CO2eq) from CH4 (AR5)  2002              0.0000
# 105444  Emissions (CO2eq) from N2O (AR5)  2002              0.0000
# 105445           Emissions (CO2eq) (AR5)  2002              0.0000
# 105446                   Emissions (CH4)  2002              0.0000
# 105447                   Emissions (N2O)  2002              0.0000
# 105448  Emissions (CO2eq) from CH4 (AR5)  2002              0.0000
# 105449  Emissions (CO2eq) from N2O (AR5)  2002              0.0000
# 105450           Emissions (CO2eq) (AR5)  2002              0.0000
# 105451                   Emissions (CH4)  2002             40.2395
# 105452                   Emissions (N2O)  2002              0.4416
# 105453                   Emissions (CO2)  2002             34.4786
# 105454  Emissions (CO2eq) from CH4 (AR5)  2002           1126.7069
# 105455  Emissions (CO2eq) from N2O (AR5)  2002            117.0249
# 105456           Emissions (CO2eq) (AR5)  2002           1278.2103
# 105457                   Emissions (CO2)  2002             44.5876
# 105458           Emissions (CO2eq) (AR5)  2002             44.5876
# 105459                   Emissions (CH4)  2002              0.0180
# 105460                   Emissions (N2O)  2002              0.0001
# 105461                   Emissions (CO2)  2002              5.1501
# 105462  Emissions (CO2eq) from CH4 (AR5)  2002              0.5040
# 105463  Emissions (CO2eq) from N2O (AR5)  2002              0.0265
# 105464           Emissions (CO2eq) (AR5)  2002              5.6806
# 105465                   Emissions (CH4)  2002              1.0761
# 105466                   Emissions (N2O)  2002              0.0005
# 105467                   Emissions (CO2)  2002             14.8957
# 105468  Emissions (CO2eq) from CH4 (AR5)  2002             30.1308
# 105469  Emissions (CO2eq) from N2O (AR5)  2002              0.1325
# 105470           Emissions (CO2eq) (AR5)  2002             45.1590
# 105471                   Emissions (CH4)  2002              0.0006
# 105472                   Emissions (N2O)  2002              0.0000
# 105473                   Emissions (CO2)  2002              1.9442
# 105474  Emissions (CO2eq) from CH4 (AR5)  2002              0.0168
# 105475  Emissions (CO2eq) from N2O (AR5)  2002              0.0000
# 105476           Emissions (CO2eq) (AR5)  2002              1.9610
# 105477                   Emissions (CH4)  2002              0.0055

# %% [markdown]
# By observing the data, we can see that some emission categories are actually subcategories for the others:
#
# - Summation of "Direct emissions(XXX)" and "Indirect emissions(XXX)" give "Emissions(XXX)"
# - "Emissions (CO2eq) from XXX (AR5)" give "Emissions (CO2eq) (AR5)"
#
# Thus we will filter out the sub-data which inflates the sum of Total Emission by Element

# %%
# Remove repition of data appearing as component and sum of same value, leaving only sums 
data_no_emission_reps =  afghanistan_data[~afghanistan_data['Element'].str.\
                                          contains('|'.join(['Direct', 'Indirect', 'from']))]
data_no_emission_reps
# Out:
#                 Area                        Item                  Element  \
# 2        Afghanistan               Crop Residues          Emissions (N2O)
# 4        Afghanistan               Crop Residues  Emissions (CO2eq) (AR5)
# 5        Afghanistan            Rice Cultivation          Emissions (CH4)
# 7        Afghanistan            Rice Cultivation  Emissions (CO2eq) (AR5)
# 8        Afghanistan     Burning - Crop residues          Emissions (CH4)
# ...              ...                         ...                      ...
# 1053994  Afghanistan     All sectors with LULUCF  Emissions (CO2eq) (AR5)
# 1053995  Afghanistan  All sectors without LULUCF          Emissions (CH4)
# 1053996  Afghanistan  All sectors without LULUCF          Emissions (N2O)
# 1053997  Afghanistan  All sectors without LULUCF          Emissions (CO2)
# 1054000  Afghanistan  All sectors without LULUCF  Emissions (CO2eq) (AR5)
#
#          Year  Total_Emissions_KT
# 2        2000              0.6370
# 4        2000            168.8070
# 5        2000             18.2000
# 7        2000            509.6000
# 8        2000              2.6471
# ...       ...                 ...
# 1053994  2020          32584.8428
# 1053995  2020            662.7644
# 1053996  2020             16.7350
# 1053997  2020           9438.0000
# 1054000  2020          32430.1854
#
# [2646 rows x 5 columns]

# %%
# Check new number of unique values in 'Element' column
print(f"Number of categories in Element: ", data_no_emission_reps['Element'].nunique())
print(f"Names of categories in Element: ", data_no_emission_reps['Element'].unique(),"\n")
# Out:
# Number of categories in Element:  4
# Names of categories in Element:  ['Emissions (N2O)' 'Emissions (CO2eq) (AR5)' 'Emissions (CH4)'
#  'Emissions (CO2)']

# %% [markdown]
# We can see that by removing sub-categorical data form the 'Element' column, the data becomes even more simplified and practical.
#
# Now, in order to make predictions based on Element we have to discard the 'Item' column and split the data in the 'Element' column into different columns corresponding to the unique values in it.

# %%
# Split 'Element' into columns
data_no_emission_reps['Total_Emissions_KT'] = pd.to_numeric(data_no_emission_reps['Total_Emissions_KT'], errors='coerce')
split_element_data = data_no_emission_reps.\
    pivot_table(index=['Year'], 
                columns='Element', 
                values='Total_Emissions_KT',
                aggfunc='sum').reset_index()



# convert the string in 'Year' column to DateTime format and set it as the index
split_element_data['Year'] = pd.to_datetime(split_element_data['Year'], format='%Y')
split_element_data.set_index(split_element_data['Year'].dt.year, inplace=True)
split_element_data.drop(columns='Year', inplace=True)
split_element_data.index.name = None
split_element_data.columns.name=None

# display the dataset
split_element_data
# Out:
#       Emissions (CH4)  Emissions (CO2)  Emissions (CO2eq) (AR5)  \
# 2000        2892.7385       -6480.3301              101424.4382
# 2001        2493.6854        3673.8078               97143.7043
# 2002        3106.4169        4709.8533              119209.0708
# 2003        3217.9286        5100.6377              123778.8238
# 2004        3224.1881        4307.1019              122946.7085
# 2005        3308.7452        5685.8623              127915.2786
# 2006        3386.0303        7059.1743              130132.8782
# 2007        3470.3567        8897.1676              133757.9607
# 2008        3820.8233       15338.2718              152305.2630
# 2009        3922.1214       24094.3183              166181.5832
# 2010        4450.9630       29993.7298              190283.1650
# 2011        4535.3023       41099.0264              204843.4108
# 2012        4504.3848       35239.1340              198318.3899
# 2013        4494.1261       28735.2476              191750.5183
# 2014        4588.1378       26340.0356              194357.4205
# 2015        4384.7020       26847.1668              188895.2772
# 2016        4337.6061       24755.1269              185232.9473
# 2017        4273.3285       28355.1053              188807.5033
# 2018        4364.8973       29805.0673              188046.4699
# 2019        4316.2723       32236.8191              189024.1671
# 2020        4491.5709       32104.1154              195495.5514
#
#       Emissions (N2O)
# 2000         101.5398
# 2001          89.2327
# 2002         103.8473
# 2003         107.8350
# 2004         107.0277
# 2005         111.6399
# 2006         106.6596
# 2007         104.4935
# 2008         113.1468
# 2009         121.7655
# 2010         134.5753
# 2011         138.7016
# 2012         139.4583
# 2013         140.3011
# 2014         149.2437
# 2015         148.2134
# 2016         147.2636
# 2017         153.9596
# 2018         135.9406
# 2019         135.5916
# 2020         141.9901

# %%
plt.figure(figsize=(16,9))
afghanistan_data.groupby(['Year'])['Total_Emissions_KT'].sum().plot.bar()
plt.xlabel('Year')
plt.ylabel('Total Emissions (KT)')
# Out:
# Text(0, 0.5, 'Total Emissions (KT)')

# %% [markdown]
# ### Functional approach to data wrangling for scaling

# %%
def clean_data(dataset: pd.DataFrame):
    """
    Drops na values and duplicates from the data
    """
    data = dataset.copy()
    data = data.dropna()
    data = data.drop_duplicates()
    
    return data

# %%
def stack_data_by_year(data: pd.DataFrame):
    """
    Stacks the individual years columns in one column to simplify the data
    """
    stacked_yr_data = pd.melt(data, 
                   id_vars=['Area', 'Item', 'Element'],
                   value_vars=data.iloc[:,4:],
                   var_name='Year',
                   value_name='Total_Emissions_KT'
    )
    
    return stacked_yr_data

# %%
def get_country_data(data: pd.DataFrame, country_name: str):
    """
    Gets the data for a particular country
    """
    country_data = data[data['Area']==country_name]
    
    return country_data

# %%
def remove_element_subcats(data: pd.DataFrame):
    """
    Removes subcategories in the 'Elements' column, leaving only sums of sub-categories
    """ 
    data_no_emission_reps = data[~data['Element'].str.\
                                contains('|'.join(['Direct', 'Indirect', 'from']))]
    
    return data_no_emission_reps

# %%
def split_element(data: pd.DataFrame):
    """
    Splits the 'Element' column into new columns for each of the unique values in the 
    'Element' column and sets the DateTime formatted 'Year' column as index
    """
    # Split 'Element' into columns
    data['Total_Emissions_KT'] = pd.to_numeric(data['Total_Emissions_KT'], errors='coerce')
    split_element_data = data.pivot_table(index=['Year'], 
                                          columns='Element', 
                                          values='Total_Emissions_KT',
                                          aggfunc='sum').reset_index()
    
    # Merge CO2 data
    split_element_data["Emissions (CO2)"] = split_element_data["Emissions (CO2)"] +\
                                            split_element_data["Emissions (CO2eq) (AR5)"]
    split_element_data = split_element_data.drop(["Emissions (CO2eq) (AR5)"], axis=1)
    
    # convert the string in 'Year' column to DateTime format and set it as the index
    split_element_data['Year'] = pd.to_datetime(split_element_data['Year'], format='%Y')
    split_element_data.set_index(split_element_data['Year'].dt.year, inplace=True)
    split_element_data.drop(columns='Year', inplace=True)
    split_element_data.index.name=None
    split_element_data.columns.name=None
    split_element_data.index = pd.to_datetime(split_element_data.index, format='%Y')
    
    return split_element_data

# %%
# Get country data from dataset

# %%
def clean_country_data(country: str, dataset: pd.DataFrame):
    """
    Stacks all the hepler functions to get clean and formatted data for one country
    """
    
    cleaned_data = clean_data(dataset)
    stacked_data = stack_data_by_year(cleaned_data)
    afghan_data = get_country_data(stacked_data, country)
    cleaned_elements = remove_element_subcats(afghan_data)
    formatted_data = split_element(cleaned_elements)
    
    return formatted_data

# %%
honduras_data = clean_country_data('Afghanistan', dataset)
honduras_data
# Out:
#             Emissions (CH4)  Emissions (CO2)  Emissions (N2O)
# 2000-01-01        2892.7385       94944.1081         101.5398
# 2001-01-01        2493.6854      100817.5121          89.2327
# 2002-01-01        3106.4169      123918.9241         103.8473
# 2003-01-01        3217.9286      128879.4615         107.8350
# 2004-01-01        3224.1881      127253.8104         107.0277
# 2005-01-01        3308.7452      133601.1409         111.6399
# 2006-01-01        3386.0303      137192.0525         106.6596
# 2007-01-01        3470.3567      142655.1283         104.4935
# 2008-01-01        3820.8233      167643.5348         113.1468
# 2009-01-01        3922.1214      190275.9015         121.7655
# 2010-01-01        4450.9630      220276.8948         134.5753
# 2011-01-01        4535.3023      245942.4372         138.7016
# 2012-01-01        4504.3848      233557.5239         139.4583
# 2013-01-01        4494.1261      220485.7659         140.3011
# 2014-01-01        4588.1378      220697.4561         149.2437
# 2015-01-01        4384.7020      215742.4440         148.2134
# 2016-01-01        4337.6061      209988.0742         147.2636
# 2017-01-01        4273.3285      217162.6086         153.9596
# 2018-01-01        4364.8973      217851.5372         135.9406
# 2019-01-01        4316.2723      221260.9862         135.5916
# 2020-01-01        4491.5709      227599.6668         141.9901

# %% [markdown]
# ### Statistical Tests

# %% [markdown]
# Visualize the data

# %%
vis_data = honduras_data

# %%
# Visualize the data
def visualize_data(vis_data: pd.DataFrame):
    """
    Visualizes the cleaned data on a column by column basis
    """
    print("Visualize Data:")
    print("="*15)
    fig, axes = plt.subplots(nrows=3, ncols=1, dpi=240, figsize=(16,11))

    for i, ax in enumerate(axes.flatten()):
        data = vis_data[vis_data.columns[i]]
        ax.plot(data, color='green', linewidth=3)

        # Formatting
        ax.set_title(vis_data.columns[i])
        ax.xaxis.set_ticks_position('none')
        ax.yaxis.set_ticks_position('none')
        ax.spines['top'].set_alpha(0)
        ax.tick_params(labelsize=10)

    plt.tight_layout();

# %%
visualize_data(vis_data)
# Out:
# Visualize Data:
# ===============

# %% [markdown]
# - Check the Stationarity of the data using the Augumented Dickey-Fuller Test

# %%
def test_statonary(ts_data, title, difference=1):
    """
    This function takes a univariate time-series data, performs the
    Augumented Dickey-Fuller test and plots the original data
    as well as an overlay of the rolling mean and standard deviation
    """
    
    rolmean = ts_data.rolling(2).mean()
    rolstd = ts_data.rolling(2).std()
    
    plt.figure(figsize=(16,9))
    plt.grid('moth')
    plt.plot(ts_data, label='Original Data')
    plt.plot(rolmean, label='Rolling Mean')
    plt.plot(rolstd, label='Rolling Std. Dev')
    plt.title(title)
    plt.legend()
    
    print("_ "*21)
    print(f"Augumented Dickey-Fuller Test: {title}\n")
    
    dft = adfuller(ts_data.diff(difference).dropna()) # Differencing appiled here: 'ts_data.diff(1)'
    dft_output = pd.Series(dft[0:4], index=['Test Statistic', 'p-value', 'No. of lags Used',
                                            'No. of obsv used'])
    
    for key, value in dft[4].items():
        dft_output['Confidence Interval (%s)'%key] = value
    print(dft_output)
    print("_ "*21)

# %%
# Loop through the columns in the dataset and run the stationarity test
for i in vis_data.columns:
    test_statonary(vis_data[i],i)
# Out:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Augumented Dickey-Fuller Test: Emissions (CH4)
#
# Test Statistic               -2.476969
# p-value                       0.121179
# No. of lags Used              8.000000
# No. of obsv used             11.000000
# Confidence Interval (1%)     -4.223238
# Confidence Interval (5%)     -3.189369
# Confidence Interval (10%)    -2.729839
# dtype: float64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Augumented Dickey-Fuller Test: Emissions (CO2)
#
# Test Statistic               -2.435084
# p-value                       0.132078
# No. of lags Used              0.000000
# No. of obsv used             19.000000
# Confidence Interval (1%)     -3.832603
# Confidence Interval (5%)     -3.031227
# Confidence Interval (10%)    -2.655520
# dtype: float64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Augumented Dickey-Fuller Test: Emissions (N2O)
#
# Test Statistic               -5.101202
# p-value                       0.000014
# No. of lags Used              0.000000
# No. of obsv used             19.000000
# Confidence Interval (1%)     -3.832603
# Confidence Interval (5%)     -3.031227
# Confidence Interval (10%)    -2.655520
# dtype: float64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _

# %% [markdown]
# From the ADF results, we can see that the data points become stationary with one differencing

# %% [markdown]
# - Carry out Granger Causality Test

# %%
def granger_test(vis_data: pd.DataFrame):
    """
    Loops through the column pair combinations in the dataset and runs
    Granger test for 1 and 2 time lags.
    
    Displays the results and returns the causality matrices for 
    1 and 2 time lags
    """
    # Initialize dataframe to hold
    causality_matrix_1TL = pd.DataFrame(index=vis_data.columns, columns= vis_data.columns)
    causality_matrix_1TL.index.name=None

    causality_matrix_2TL = pd.DataFrame(index=vis_data.columns, columns= vis_data.columns)
    causality_matrix_2TL.index.name=None
    
    for i in vis_data.columns:
        for j in vis_data.columns:
            if i!=j:
                print(f"{i} causes {j}?\n", "_ "*11)
                granger = grangercausalitytests(vis_data[[i,j]],2)
                print("="*30,"\n")
                causality_matrix_1TL[i][j] = granger[1][0]['ssr_ftest'][1]
                causality_matrix_2TL[i][j] = granger[2][0]['ssr_ftest'][1]
    
    return causality_matrix_1TL, causality_matrix_2TL

# %%
causality_matrix_1TL, causality_matrix_2TL = granger_test(vis_data)
# Out:
# Emissions (CH4) causes Emissions (CO2)?
#  _ _ _ _ _ _ _ _ _ _ _
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=8.3764  , p=0.0101  , df_denom=17, df_num=1
# ssr based chi2 test:   chi2=9.8546  , p=0.0017  , df=1
# likelihood ratio test: chi2=8.0121  , p=0.0046  , df=1
# parameter F test:         F=8.3764  , p=0.0101  , df_denom=17, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.0098  , p=0.0818  , df_denom=14, df_num=2
# ssr based chi2 test:   chi2=8.1696  , p=0.0168  , df=2
# likelihood ratio test: chi2=6.7955  , p=0.0334  , df=2
# parameter F test:         F=3.0098  , p=0.0818  , df_denom=14, df_num=2
# ==============================
#
# Emissions (CH4) causes Emissions (N2O)?
#  _ _ _ _ _ _ _ _ _ _ _
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.3846  , p=0.2555  , df_denom=17, df_num=1
# ssr based chi2 test:   chi2=1.6290  , p=0.2018  , df=1
# likelihood ratio test: chi2=1.5661  , p=0.2108  , df=1
# parameter F test:         F=1.3846  , p=0.2555  , df_denom=17, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.0750  , p=0.1625  , df_denom=14, df_num=2
# ssr based chi2 test:   chi2=5.6322  , p=0.0598  , df=2
# likelihood ratio test: chi2=4.9327  , p=0.0849  , df=2
# parameter F test:         F=2.0750  , p=0.1625  , df_denom=14, df_num=2
# ==============================
#
# Emissions (CO2) causes Emissions (CH4)?
#  _ _ _ _ _ _ _ _ _ _ _
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0508  , p=0.8244  , df_denom=17, df_num=1
# ssr based chi2 test:   chi2=0.0597  , p=0.8069  , df=1
# likelihood ratio test: chi2=0.0596  , p=0.8071  , df=1
# parameter F test:         F=0.0508  , p=0.8244  , df_denom=17, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8305  , p=0.4562  , df_denom=14, df_num=2
# ssr based chi2 test:   chi2=2.2543  , p=0.3240  , df=2
# likelihood ratio test: chi2=2.1303  , p=0.3447  , df=2
# parameter F test:         F=0.8305  , p=0.4562  , df_denom=14, df_num=2
# ==============================
#
# Emissions (CO2) causes Emissions (N2O)?
#  _ _ _ _ _ _ _ _ _ _ _
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.0536  , p=0.0986  , df_denom=17, df_num=1
# ssr based chi2 test:   chi2=3.5924  , p=0.0580  , df=1
# likelihood ratio test: chi2=3.3039  , p=0.0691  , df=1
# parameter F test:         F=3.0536  , p=0.0986  , df_denom=17, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4296  , p=0.6591  , df_denom=14, df_num=2
# ssr based chi2 test:   chi2=1.1660  , p=0.5582  , df=2
# likelihood ratio test: chi2=1.1316  , p=0.5679  , df=2
# parameter F test:         F=0.4296  , p=0.6591  , df_denom=14, df_num=2
# ==============================
#
# Emissions (N2O) causes Emissions (CH4)?
#  _ _ _ _ _ _ _ _ _ _ _
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.6361  , p=0.0196  , df_denom=17, df_num=1
# ssr based chi2 test:   chi2=7.8072  , p=0.0052  , df=1
# likelihood ratio test: chi2=6.5913  , p=0.0102  , df=1
# parameter F test:         F=6.6361  , p=0.0196  , df_denom=17, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.5028  , p=0.0584  , df_denom=14, df_num=2
# ssr based chi2 test:   chi2=9.5077  , p=0.0086  , df=2
# likelihood ratio test: chi2=7.7090  , p=0.0212  , df=2
# parameter F test:         F=3.5028  , p=0.0584  , df_denom=14, df_num=2
# ==============================
#
# Emissions (N2O) causes Emissions (CO2)?
#  _ _ _ _ _ _ _ _ _ _ _
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=9.6595  , p=0.0064  , df_denom=17, df_num=1
# ssr based chi2 test:   chi2=11.3641 , p=0.0007  , df=1
# likelihood ratio test: chi2=8.9986  , p=0.0027  , df=1
# parameter F test:         F=9.6595  , p=0.0064  , df_denom=17, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.9171  , p=0.0873  , df_denom=14, df_num=2
# ssr based chi2 test:   chi2=7.9178  , p=0.0191  , df=2
# likelihood ratio test: chi2=6.6186  , p=0.0365  , df=2
# parameter F test:         F=2.9171  , p=0.0873  , df_denom=14, df_num=2
# ==============================

# %%
causality_matrix_1TL
# Out:
#                 Emissions (CH4) Emissions (CO2) Emissions (N2O)
# Emissions (CH4)             NaN         0.82443       0.0196269
# Emissions (CO2)       0.0100858             NaN      0.00639434
# Emissions (N2O)        0.255525       0.0985978             NaN

# %%
causality_matrix_2TL
# Out:
#                 Emissions (CH4) Emissions (CO2) Emissions (N2O)
# Emissions (CH4)             NaN        0.456192       0.0584169
# Emissions (CO2)       0.0817895             NaN       0.0872963
# Emissions (N2O)        0.162462        0.659087             NaN

# %% [markdown]
# From the causality matrices, it can be observed that the causality relationships largely fade after one time lag between the features in the dataset

# %% [markdown]
# ### Train Test Split

# %%
def train_test_split(data: pd.DataFrame, test_samples: int):
    """
    Splits the data into train and test based on the specified number
    of test samples
    """
    train_df = data[:-test_samples]
    test_df = data[-test_samples:]
    print("train_df: ",train_df.shape, "test_df: ",test_df.shape)
    return train_df, test_df

# %%
train_df, test_df = train_test_split(vis_data, test_samples=3)
# Out:
# train_df:  (18, 3) test_df:  (3, 3)

# %% [markdown]
# ### Build Model

# %% [markdown]
# ##### Hyperparameter Tuning

# %% [markdown]
# Use brute force to check through combination of p and d values which yields best RMSE

# %%
def varmax_model(train_df, varmax_order):
    """
    Fits a VARMAX model with the specified order, makes predictions and
    checks the RMSE with respect to test set specified in 'get_best_model'
    function
    """
    # train the model
    var_model = VARMAX(train_df, order=varmax_order, enforce_stationarity=True)
    model_fit = var_model.fit(disp=False)
    
    # set forecast range
    start = dt.datetime(year=2018, month=1, day=1)
    end = dt.datetime(year=2020, month=1, day=1)

    # Make forecasts
    predict = model_fit.get_prediction(start=start, end=end)
    predictions = predict.predicted_mean
    
    RMSE = {'Emissions (CH4)':0, 'Emissions (CO2)':0, 'Emissions (N2O)':0}
    for i,j in zip(predictions.columns, test_df.columns):
        rmse = np.sqrt(mean_squared_error(predictions[i], test_df[j]))
        RMSE[j] = rmse
    
    return RMSE

# %%
def get_best_model(train, test, max_pd_val):
    """
    Generates sequences of p,d values for model training, trains multiple
    models using 'varmax_model' function and prints the best
    model configuration and RMSE score.
    
    Returns best model RMSE score and best config
    """
    # initialize p and d value for model training
    p_d_vals = [list(range(0,max_pd_val+1)), list(range(0,max_pd_val+1))]
    p_d_vals = list(itertools.product(*p_d_vals))[1:]
    
    # intialize 'best_score' and 'best_cfg'
    best_score = {'Emissions (CH4)':float('inf'), 
                  'Emissions (CO2)':float('inf'), 
                  'Emissions (N2O)':float('inf')}
    best_cfg = None
    
    for i in p_d_vals:
        varmax_order = (i[0],i[1])
        RMSE = varmax_model(train_df, varmax_order)

        try:
            if  RMSE['Emissions (CH4)']<best_score['Emissions (CH4)'] and\
                RMSE['Emissions (CO2)']<best_score['Emissions (CO2)'] and\
                RMSE['Emissions (N2O)']<best_score['Emissions (N2O)']:
                best_score  = RMSE
                best_cfg = varmax_order
                print(RMSE, order)
        except:
            continue
                
    print("best rmse: {} \nbest_cfg: {}".format(best_score, best_cfg))
    return best_score, best_cfg

# %%
best_model = get_best_model(train_df, test_df, max_pd_val=3)
# Out:
# best rmse: {'Emissions (CH4)': 525.5933956592181, 'Emissions (CO2)': 41306.37380902904, 'Emissions (N2O)': 14.531873417418291}
# best_cfg: (0, 1)

# %% [markdown]
# Use built-in parameter checker

# %%
# check for best model parameters 
# Apply one differencing since it showed positive effect in ADF test
def inbuilt_checker(train_df: pd.DataFrame, difference=1):
    """
    Uses the built-in parameter checking system of the VAR module
    to display the model parameters with respect to different time lags.
    
    Uses * to mark the best parameter values for each time lag.
    
    Pick best AR p value by visually inspecting to see time lag with
    the most '*'s
    """
    model = VAR(train_df.diff(difference).dropna())
    sorted_order = model.select_order()
    return sorted_order.summary()

# %%
inbuilt_checker(train_df, difference=1)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ##### Train Model

# %% [markdown]
# The model will be initialized with 2 time lags since that vaule has the best set of statistical measures with brute force and the in-built checker

# %%
# Fit the model
def train_model(train_df: pd.DataFrame, order: tuple):
    """
    Fits a VARMAX model based on specified training data and p,d order
    """
    var_model = VARMAX(train_df, order=(order[0],order[1]), enforce_stationarity=True )
    model_fit = var_model.fit(disp=False)
    print(model_fit.summary())
    return model_fit

# %%
model_fit = train_model(train_df, (2,0))
# Out:
#                                                Statespace Model Results
# =====================================================================================================================
# Dep. Variable:     ['Emissions (CH4)', 'Emissions (CO2)', 'Emissions (N2O)']   No. Observations:                   18
# Model:                                                                VAR(2)   Log Likelihood                -345.714
#                                                                  + intercept   AIC                            745.428
# Date:                                                       Wed, 12 Apr 2023   BIC                            769.468
# Time:                                                               12:21:08   HQIC                           748.743
# Sample:                                                           01-01-2000
#                                                                 - 01-01-2017
# Covariance Type:                                                         opg
# ===================================================================================
# Ljung-Box (L1) (Q):       0.47, 1.43, 0.30   Jarque-Bera (JB):     1.43, 0.66, 0.88
# Prob(Q):                  0.49, 0.23, 0.58   Prob(JB):             0.49, 0.72, 0.64
# Heteroskedasticity (H):   0.46, 0.43, 1.35   Skew:               -0.68, 0.16, -0.26
# Prob(H) (two-sided):      0.37, 0.33, 0.73   Kurtosis:             3.24, 2.11, 2.05
#                          Results for equation Emissions (CH4)
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# intercept           1339.6800      1.051   1275.126      0.000    1337.621    1341.739
# L1.Emissions (CH4)     0.3456      1.818      0.190      0.849      -3.218       3.910
# L1.Emissions (CO2)     0.0066      0.047      0.141      0.888      -0.085       0.098
# L1.Emissions (N2O)    -7.1091     20.407     -0.348      0.728     -47.106      32.888
# L2.Emissions (CH4)     0.9933      1.130      0.879      0.379      -1.221       3.207
# L2.Emissions (CO2)    -0.0056      0.034     -0.165      0.869      -0.072       0.061
# L2.Emissions (N2O)   -14.8781      9.319     -1.596      0.110     -33.144       3.388
#                          Results for equation Emissions (CO2)
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# intercept          -3.999e+04      0.141  -2.84e+05      0.000      -4e+04      -4e+04
# L1.Emissions (CH4)    26.5931     39.377      0.675      0.499     -50.585     103.771
# L1.Emissions (CO2)     1.1323      1.865      0.607      0.544      -2.524       4.789
# L1.Emissions (N2O)  -629.4762      0.734   -857.631      0.000    -630.915    -628.038
# L2.Emissions (CH4)    45.2391     23.327      1.939      0.052      -0.481      90.959
# L2.Emissions (CO2)    -0.9674      1.268     -0.763      0.446      -3.453       1.518
# L2.Emissions (N2O)   -53.1147      0.958    -55.434      0.000     -54.993     -51.237
#                          Results for equation Emissions (N2O)
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# intercept             18.2850      5.700      3.208      0.001       7.113      29.456
# L1.Emissions (CH4)    -0.0074      0.090     -0.081      0.935      -0.185       0.170
# L1.Emissions (CO2)     0.0001      0.002      0.077      0.939      -0.004       0.004
# L1.Emissions (N2O)     0.7182      0.931      0.772      0.440      -1.106       2.543
# L2.Emissions (CH4)     0.0184      0.078      0.235      0.814      -0.135       0.172
# L2.Emissions (CO2)    -0.0002      0.001     -0.104      0.917      -0.003       0.003
# L2.Emissions (N2O)    -0.1734      1.175     -0.148      0.883      -2.476       2.130
#                                           Error covariance matrix
# ============================================================================================================
#                                                coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# sqrt.var.Emissions (CH4)                   185.6506     40.693      4.562      0.000     105.894     265.407
# sqrt.cov.Emissions (CH4).Emissions (CO2)  1.163e+04      0.283   4.11e+04      0.000    1.16e+04    1.16e+04
# sqrt.var.Emissions (CO2)                  5650.2755      0.437   1.29e+04      0.000    5649.419    5651.132
# sqrt.cov.Emissions (CH4).Emissions (N2O)     6.0088      3.699      1.624      0.104      -1.242      13.259
# sqrt.cov.Emissions (CO2).Emissions (N2O)     1.3641      2.906      0.469      0.639      -4.331       7.059
# sqrt.var.Emissions (N2O)                     3.2156      1.937      1.660      0.097      -0.581       7.013
# ============================================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.29e+21. Standard errors may be unstable.

# %% [markdown]
# ### Make Predictions & Evaluate Model

# %%
def predict_data(model, start_year: int, end_year: int):
    """
    Makes predictions using specified model and period from start_year 
    to end_year and returns the predictions as a DataFrame
    """
    # set date range to forecast
    start = dt.datetime(year=start_year, month=1, day=1)
    end = dt.datetime(year=end_year, month=1, day=1)

    # Make forecasts
    predict = model.get_prediction(start=start, end=end)
    predictions = predict.predicted_mean
    
    # Format dataframe
    predictions.columns=['Emissions (CH4)_predicted', 
                         'Emissions (CO2)_predicted', 
                         'Emissions (N2O)_predicted']
    
    return predictions

# %%
predictions = predict_data(model_fit, 2018, 2020)
predictions
# Out:
#             Emissions (CH4)_predicted  Emissions (CO2)_predicted  \
# 2018-01-01                4095.100020              207895.093585
# 2019-01-01                3783.448909              183769.020897
# 2020-01-01                3457.849491              152311.244436
#
#             Emissions (N2O)_predicted
# 2018-01-01                 151.876791
# 2019-01-01                 146.897619
# 2020-01-01                 140.539684

# %% [markdown]
# Visual Comparison

# %%
def visual_eval(test_df: pd.DataFrame, predictions: pd.DataFrame, vis_data: pd.DataFrame):
    """
    Generates visulization of an overlay of training, test and predicted data for each
    feature
    """
    # concatenate test_df and predictions
    test_n_predictions = pd.concat([test_df, predictions], axis=1)
    
    # plot CO2 data (because CO2 values are very high compared to the other Elements)
    plt.figure(figsize=(16,9))
    plt.title('Emissions (CO2)')
    plt.plot(test_n_predictions['Emissions (CO2)'], label= 'Test') 
    plt.plot(test_n_predictions['Emissions (CO2)_predicted'], label = 'Predicted') 
    plt.plot(vis_data['Emissions (CO2)']['2010-01-01':test_df.index[-len(test_df)]], label= 'Train')
    plt.legend()
    
    plt.figure(figsize=(16,9))
    plt.title('Emissions (CH4)')
    plt.plot(test_n_predictions['Emissions (CH4)'], label= 'Test') 
    plt.plot(test_n_predictions['Emissions (CH4)_predicted'], label = 'Predicted') 
    plt.plot(vis_data['Emissions (CH4)']['2010-01-01':test_df.index[-len(test_df)]], label= 'Train')
    plt.legend()
    
    plt.figure(figsize=(16,9))
    plt.title('Emissions (N2O)')    
    plt.plot(test_n_predictions['Emissions (N2O)'], label= 'Test') 
    plt.plot(test_n_predictions['Emissions (N2O)_predicted'], label = 'Predicted') 
    plt.plot(vis_data['Emissions (N2O)']['2010-01-01':test_df.index[-len(test_df)]], label= 'Train')
    plt.legend()

# %%
visual_eval(test_df, predictions, vis_data)

# %% [markdown]
# Statistical Evaluation

# %%
def stat_eval(test_df: pd.DataFrame, predictions: pd.DataFrame):
    """
    Carries out statistical evaluation of model based on test data and 
    prediction. 
    
    Prints and returns a summary dictionary
    """
    # statistical evaluations
    RMSE = {'Emissions (CH4)':0, 'Emissions (CO2)':0, 'Emissions (N2O)':0}
    
    print("="*5,"Statistical Eval","="*5,"\n")
    for i,j in zip(predictions.columns, test_df.columns):
        rmse = math.sqrt(mean_squared_error(predictions[i], test_df[j]))
        RMSE[j] = rmse
        print(f"Mean val {j}: {round(mean(test_df[j]), 4)} -- RMSE: {round(rmse, 4)}",
             f"-- RMSE < 10% Mean: ", round(rmse, 4)< round(mean(test_df[j]), 4)/10)
                    
    return RMSE

# %%
RMSE = stat_eval(test_df, predictions)
# Out:
# ===== Statistical Eval =====
#
# Mean val Emissions (CH4): 40251.2775 -- RMSE: 1364.2692 -- RMSE < 10% Mean:  True
# Mean val Emissions (CO2): 3067217.6172 -- RMSE: 32580.5628 -- RMSE < 10% Mean:  True
# Mean val Emissions (N2O): 1085.2707 -- RMSE: 13.5402 -- RMSE < 10% Mean:  True

# %% [markdown]
# It can be observed that for most of the targets the RMSE is <10% of the mean, indicating good predictive power

# %%
RMSE
# Out:
# {'Emissions (CH4)': 1364.2692323360172,
#  'Emissions (CO2)': 32580.56279062867,
#  'Emissions (N2O)': 13.5402321823468}

# %% [markdown]
# # Pipelines

# %% [markdown]
# ### Data Pipeline

# %%
def clean_country_data(country: str, dataset: pd.DataFrame):
    """
    Stacks all the hepler functions to get clean and formatted data for one country
    """
    
    cleaned_data = clean_data(dataset)
    stacked_data = stack_data_by_year(cleaned_data)
    afghan_data = get_country_data(stacked_data, country)
    cleaned_elements = remove_element_subcats(afghan_data)
    formatted_data = split_element(cleaned_elements)
    
    return formatted_data

# %% [markdown]
# ### Statistical Tests Pipeline

# %%
def stat_tests(vis_data):
    """
    Takes cleaned data as input and calls all the functions needed
    for statistical tests sequentially and prints the results
    """

    # visualize the data
    print("Data Visualization")
    print("="*30)
    visualize_data(vis_data) 
    
    # check for stationarity
    print("\nStationarity Test")
    print("="*30)
    for i in vis_data.columns:
        test_statonary(vis_data[i],i)
        
    # carry out granger test 
    print("\nGranger Causality Test")
    print("="*30)
    causality_matrix_1TL, causality_matrix_2TL = granger_test(vis_data)
    print("Causality Matrix (1 Time Lag):\n",causality_matrix_1TL)
    print("Causality Matrix (2 Time Lags):\n",causality_matrix_2TL)

# %%
stat_tests(vis_data)
# Out:
# Data Visualization
# ==============================
# Visualize Data:
# ===============
#
# Stationarity Test
# ==============================
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Augumented Dickey-Fuller Test: Emissions (CH4)
#
# Test Statistic               -1.210884
# p-value                       0.668896
# No. of lags Used              7.000000
# No. of obsv used             12.000000
# Confidence Interval (1%)     -4.137829
# Confidence Interval (5%)     -3.154972
# Confidence Interval (10%)    -2.714477
# dtype: float64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Augumented Dickey-Fuller Test: Emissions (CO2)
#
# Test Statistic               -1.260850
# p-value                       0.646888
# No. of lags Used              7.000000
# No. of obsv used             12.000000
# Confidence Interval (1%)     -4.137829
# Confidence Interval (5%)     -3.154972
# Confidence Interval (10%)    -2.714477
# dtype: float64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Augumented Dickey-Fuller Test: Emissions (N2O)
#
# Test Statistic               -2.416367
# p-value                       0.137170
# No. of lags Used              2.000000
# No. of obsv used             17.000000
# Confidence Interval (1%)     -3.889266
# Confidence Interval (5%)     -3.054358
# Confidence Interval (10%)    -2.666984
# dtype: float64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# Granger Causality Test
# ==============================
# Emissions (CH4) causes Emissions (CO2)?
#  _ _ _ _ _ _ _ _ _ _ _
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.7534  , p=0.0695  , df_denom=17, df_num=1
# ssr based chi2 test:   chi2=4.4158  , p=0.0356  , df=1
# likelihood ratio test: chi2=3.9899  , p=0.0458  , df=1
# parameter F test:         F=3.7534  , p=0.0695  , df_denom=17, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.5478  , p=0.0567  , df_denom=14, df_num=2
# ssr based chi2 test:   chi2=9.6297  , p=0.0081  , df=2
# likelihood ratio test: chi2=7.7901  , p=0.0203  , df=2
# parameter F test:         F=3.5478  , p=0.0567  , df_denom=14, df_num=2
# ==============================
#
# Emissions (CH4) causes Emissions (N2O)?
#  _ _ _ _ _ _ _ _ _ _ _
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.6841  , p=0.0450  , df_denom=17, df_num=1
# ssr based chi2 test:   chi2=5.5108  , p=0.0189  , df=1
# likelihood ratio test: chi2=4.8674  , p=0.0274  , df=1
# parameter F test:         F=4.6841  , p=0.0450  , df_denom=17, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.3732  , p=0.0335  , df_denom=14, df_num=2
# ssr based chi2 test:   chi2=11.8701 , p=0.0026  , df=2
# likelihood ratio test: chi2=9.2216  , p=0.0099  , df=2
# parameter F test:         F=4.3732  , p=0.0335  , df_denom=14, df_num=2
# ==============================
#
# Emissions (CO2) causes Emissions (CH4)?
#  _ _ _ _ _ _ _ _ _ _ _
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3093  , p=0.5853  , df_denom=17, df_num=1
# ssr based chi2 test:   chi2=0.3639  , p=0.5463  , df=1
# likelihood ratio test: chi2=0.3606  , p=0.5482  , df=1
# parameter F test:         F=0.3093  , p=0.5853  , df_denom=17, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8834  , p=0.4352  , df_denom=14, df_num=2
# ssr based chi2 test:   chi2=2.3978  , p=0.3015  , df=2
# likelihood ratio test: chi2=2.2581  , p=0.3233  , df=2
# parameter F test:         F=0.8834  , p=0.4352  , df_denom=14, df_num=2
# ==============================
#
# Emissions (CO2) causes Emissions (N2O)?
#  _ _ _ _ _ _ _ _ _ _ _
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.4319  , p=0.0323  , df_denom=17, df_num=1
# ssr based chi2 test:   chi2=6.3905  , p=0.0115  , df=1
# likelihood ratio test: chi2=5.5454  , p=0.0185  , df=1
# parameter F test:         F=5.4319  , p=0.0323  , df_denom=17, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.9961  , p=0.0826  , df_denom=14, df_num=2
# ssr based chi2 test:   chi2=8.1322  , p=0.0171  , df=2
# likelihood ratio test: chi2=6.7694  , p=0.0339  , df=2
# parameter F test:         F=2.9961  , p=0.0826  , df_denom=14, df_num=2
# ==============================
#
# Emissions (N2O) causes Emissions (CH4)?
#  _ _ _ _ _ _ _ _ _ _ _
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.2055  , p=0.1558  , df_denom=17, df_num=1
# ssr based chi2 test:   chi2=2.5947  , p=0.1072  , df=1
# likelihood ratio test: chi2=2.4397  , p=0.1183  , df=1
# parameter F test:         F=2.2055  , p=0.1558  , df_denom=17, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1517  , p=0.8606  , df_denom=14, df_num=2
# ssr based chi2 test:   chi2=0.4118  , p=0.8139  , df=2
# likelihood ratio test: chi2=0.4074  , p=0.8157  , df=2
# parameter F test:         F=0.1517  , p=0.8606  , df_denom=14, df_num=2
# ==============================
#
# Emissions (N2O) causes Emissions (CO2)?
#  _ _ _ _ _ _ _ _ _ _ _
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3106  , p=0.5846  , df_denom=17, df_num=1
# ssr based chi2 test:   chi2=0.3654  , p=0.5455  , df=1
# likelihood ratio test: chi2=0.3621  , p=0.5473  , df=1
# parameter F test:         F=0.3106  , p=0.5846  , df_denom=17, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1735  , p=0.8425  , df_denom=14, df_num=2
# ssr based chi2 test:   chi2=0.4710  , p=0.7902  , df=2
# likelihood ratio test: chi2=0.4652  , p=0.7925  , df=2
# parameter F test:         F=0.1735  , p=0.8425  , df_denom=14, df_num=2
# ==============================
#
# Causality Matrix (1 Time Lag):
#                  Emissions (CH4) Emissions (CO2) Emissions (N2O)
# Emissions (CH4)             NaN        0.585345        0.155826
# Emissions (CO2)       0.0694966             NaN        0.584566
# Emissions (N2O)       0.0449671       0.0323419             NaN
# Causality Matrix (2 Time Lags):
#                  Emissions (CH4) Emissions (CO2) Emissions (N2O)
# Emissions (CH4)             NaN        0.435209         0.86063
# Emissions (CO2)       0.0566973             NaN         0.84249
# Emissions (N2O)       0.0334589       0.0825806             NaN

# %% [markdown]
# ### Tuning Pipeline

# %%
def tune_model(vis_data, test_samples=3, max_pd_val=2):
    """
    Takes clean data, number of test sets required and max value for p and p.
    
    Splits data into train and test sets, calls functions for brute force 
    hyperparameter tuning as well as built-in VAR tuner and prints results
    """
    # train-test split
    train_df, test_df = train_test_split(vis_data, test_samples)
    
    # hyperparameter tuning
    print("\nHyperparameter tuning:")
    print("\nBrute force tuning:")
    print("="*15)
    print(get_best_model(train_df, test_df, max_pd_val))
    
    print("\nIn-built Checker:")
    print("="*15)
    print(inbuilt_checker(train_df, difference=1))

# %%
tune_model(vis_data, test_samples=3, max_pd_val=2)
# Out:
# train_df:  (18, 3) test_df:  (3, 3)
#
# Hyperparameter tuning:
#
# Brute force tuning:
# ===============
# best rmse: {'Emissions (CH4)': 1364.2692323360172, 'Emissions (CO2)': 32580.56279062867, 'Emissions (N2O)': 13.5402321823468}
# best_cfg: (2, 0)
# None
#
# In-built Checker:
# ===============
#  VAR Order Selection (* highlights the minimums)
# =================================================
#       AIC         BIC         FPE         HQIC
# -------------------------------------------------
# 0       42.77      42.91*   3.753e+18       42.76
# 1       43.08       43.63   5.378e+18       43.03
# 2       42.82       43.78   5.316e+18       42.73
# 3      41.64*       43.01  3.597e+18*      41.51*
# -------------------------------------------------

# %% [markdown]
# ### Model Pipeline

# %%
def model_training(vis_data, test_samples=3, varmax_order: tuple=(2,0)):
    """
    Takes clean data, number of test samples reqired and tuple of p,d values 
    and returns fit model.
    
    Splits the clean data into train and test set, fits VARMAX model on train
    set with specified p,d values, makes predictions corresponding to number 
    of test samples and performs visual and statistical evaluation of the model.
    
    Prints the model statistical evaluation summary and returns the model.
    """
    # train-test split
    train_df, test_df = train_test_split(vis_data, test_samples)
    
    # train model
    print("\nModel Info:")
    print("="*15)
    model_fit = train_model(train_df, (varmax_order[0],varmax_order[1]))
    
    # make predictions
    predictions = predict_data(model_fit, 2020-test_samples+1, 2020)
    print("\nPredictions:")
    print("="*15)
    print(predictions)
    
    # model evaluation
    print("\nVisual Evaluation:")
    print("="*15)
    visual_eval(test_df, predictions, vis_data)
    
    RMSE = stat_eval(test_df, predictions)
    
    print(RMSE)
    
    
    return model_fit

# %%
model_training(vis_data, test_samples=3, order=(2,0))
# Out:
# train_df:  (18, 3) test_df:  (3, 3)
#
# Model Info:
# ===============
#                                                Statespace Model Results
# =====================================================================================================================
# Dep. Variable:     ['Emissions (CH4)', 'Emissions (CO2)', 'Emissions (N2O)']   No. Observations:                   18
# Model:                                                                VAR(2)   Log Likelihood                -467.734
#                                                                  + intercept   AIC                            989.469
# Date:                                                       Wed, 12 Apr 2023   BIC                           1013.509
# Time:                                                               12:04:30   HQIC                           992.784
# Sample:                                                           01-01-2000
#                                                                 - 01-01-2017
# Covariance Type:                                                         opg
# ===================================================================================
# Ljung-Box (L1) (Q):       0.01, 1.43, 0.17   Jarque-Bera (JB):     0.42, 4.15, 0.20
# Prob(Q):                  0.91, 0.23, 0.68   Prob(JB):             0.81, 0.13, 0.91
# Heteroskedasticity (H):   0.26, 0.38, 1.74   Skew:               -0.17, -0.91, 0.24
# Prob(H) (two-sided):      0.13, 0.26, 0.52   Kurtosis:             2.33, 4.48, 2.80
#                          Results for equation Emissions (CH4)
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# intercept           8830.7305      0.264   3.34e+04      0.000    8830.213    8831.248
# L1.Emissions (CH4)     0.7121      0.807      0.882      0.378      -0.871       2.295
# L1.Emissions (CO2)    -0.0026      0.014     -0.196      0.845      -0.029       0.024
# L1.Emissions (N2O)     8.1649     25.910      0.315      0.753     -42.617      58.947
# L2.Emissions (CH4)    -0.0456      0.456     -0.100      0.920      -0.940       0.849
# L2.Emissions (CO2)     0.0020      0.008      0.247      0.805      -0.014       0.018
# L2.Emissions (N2O)    -1.3839     19.524     -0.071      0.943     -39.650      36.883
#                          Results for equation Emissions (CO2)
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# intercept           9.756e+05        nan        nan        nan         nan         nan
# L1.Emissions (CH4)    11.6383     34.771      0.335      0.738     -56.512      79.789
# L1.Emissions (CO2)     0.4427      1.188      0.373      0.709      -1.886       2.772
# L1.Emissions (N2O)  1032.3697      0.609   1695.157      0.000    1031.176    1033.563
# L2.Emissions (CH4)    -2.2287     34.682     -0.064      0.949     -70.203      65.746
# L2.Emissions (CO2)    -0.3415      0.913     -0.374      0.708      -2.130       1.447
# L2.Emissions (N2O)   234.4934      0.475    493.310      0.000     233.562     235.425
#                          Results for equation Emissions (N2O)
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# intercept             61.4483      3.656     16.807      0.000      54.283      68.614
# L1.Emissions (CH4)    -0.0106      0.023     -0.461      0.645      -0.056       0.035
# L1.Emissions (CO2)     0.0001      0.001      0.179      0.858      -0.001       0.002
# L1.Emissions (N2O)     0.9555      1.308      0.730      0.465      -1.609       3.520
# L2.Emissions (CH4)    -0.0004      0.031     -0.012      0.991      -0.061       0.060
# L2.Emissions (CO2)  2.872e-05      0.000      0.060      0.952      -0.001       0.001
# L2.Emissions (N2O)    -0.0806      1.384     -0.058      0.954      -2.794       2.633
#                                           Error covariance matrix
# ============================================================================================================
#                                                coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# sqrt.var.Emissions (CH4)                  1470.9766      5.062    290.597      0.000    1461.055    1480.898
# sqrt.cov.Emissions (CH4).Emissions (CO2)  8.615e+04      0.021   4.09e+06      0.000    8.61e+04    8.61e+04
# sqrt.var.Emissions (CO2)                  8.226e+04      0.055    1.5e+06      0.000    8.23e+04    8.23e+04
# sqrt.cov.Emissions (CH4).Emissions (N2O)    14.4271     16.455      0.877      0.381     -17.824      46.678
# sqrt.cov.Emissions (CO2).Emissions (N2O)    30.9337     19.800      1.562      0.118      -7.874      69.741
# sqrt.var.Emissions (N2O)                    25.4969     15.332      1.663      0.096      -4.553      55.547
# ============================================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.94e+22. Standard errors may be unstable.
#
# Predictions:
# ===============
#             Emissions (CH4)_predicted  Emissions (CO2)_predicted  \
# 2018-01-01               41023.231929               3.031565e+06
# 2019-01-01               41448.941835               3.036270e+06
# 2020-01-01               41937.903708               3.036853e+06
#
#             Emissions (N2O)_predicted
# 2018-01-01                1063.814951
# 2019-01-01                1077.044450
# 2020-01-01                1086.715346
#
# Visual Evaluation:
# ===============
# ===== Statistical Eval =====
#
# Mean val Emissions (CH4): 40251.2775 -- RMSE: 1364.2692 -- RMSE < 10% Mean:  True
# Mean val Emissions (CO2): 3067217.6172 -- RMSE: 32580.5628 -- RMSE < 10% Mean:  True
# Mean val Emissions (N2O): 1085.2707 -- RMSE: 13.5402 -- RMSE < 10% Mean:  True
# {'Emissions (CH4)': 1364.2692323360172, 'Emissions (CO2)': 32580.56279062867, 'Emissions (N2O)': 13.5402321823468}

# %% [markdown]
# ### Forecast Pipeline

# %%
def forecast_data(model, start_year: int, end_year: int):
    """
    Takes model, forcast start_year and end_year as input and
    returns dataframe with forecast data.
    """
    
    # set date range to forecast
    start = dt.datetime(year=start_year, month=1, day=1)
    end = dt.datetime(year=end_year, month=1, day=1)

    # Make forecasts
    predict = model.get_prediction(start=start, end=end)
    forecast = predict.predicted_mean
    
    # Format dataframe
    forecast.columns=['Emissions (CH4)_predicted', 
                         'Emissions (CO2)_predicted', 
                         'Emissions (N2O)_predicted']
    
    return forecast


def visual_forecast(predictions: pd.DataFrame, vis_data: pd.DataFrame, country: str):
    """
    Takes forecast dataframe, existing data dataframe and country name as input and
    visualizes and overlay of existing data and forecast data fro each column of data
    """
    
    # plot CO2 data (because CO2 values are very high compared to the other Elements)
    plt.figure(figsize=(16,9))
    plt.title(f'Emissions (CO2) from {country}', weight='bold')
    plt.plot(predictions['Emissions (CO2)_predicted'], label = 'Forecast') 
    plt.plot(vis_data['Emissions (CO2)'], label= 'Current')
    plt.xlabel('Years', weight='bold')
    plt.ylabel('Emissions (KiloTonnes)', weight='bold')
    plt.legend()
    
    plt.figure(figsize=(16,9))
    plt.title(f'Emissions (CH4) from {country}', weight='bold')
    plt.plot(predictions['Emissions (CH4)_predicted'], label = 'Forecast') 
    plt.plot(vis_data['Emissions (CH4)'], label= 'Current')
    plt.xlabel('Years', weight='bold')
    plt.ylabel('Emissions (KiloTonnes)', weight='bold')
    plt.legend()
    
    plt.figure(figsize=(16,9))
    plt.title(f'Emissions (N2O) from {country}', weight='bold')    
    plt.plot(predictions['Emissions (N2O)_predicted'], label = 'Forecast') 
    plt.plot(vis_data['Emissions (N2O)'], label= 'Current')
    plt.xlabel('Years', weight='bold')
    plt.ylabel('Emissions (KiloTonnes)', weight='bold')
    plt.legend()

# %% [markdown]
# # Grand Pipeline

# %%
def run(vis_data: pd.DataFrame, tune: bool=True):
    """
    Takes clean data and tune boolean value. Runs stat test pipeline
    and tune pipeline if tune is set to true, else, skips tuning and 
    runs model pipeline based on set parameters
    
    Returns fit model
    """
    
    stat_tests(vis_data)
    
    if tune == True:
        tune_model(vis_data, test_samples=3, max_pd_val=3)
    
    result = model_training(vis_data, test_samples=3, varmax_order=(2,0))
    
    return result

# %% [markdown]
# # Demo

# %% [markdown]
# Run data, stat and model pipelines

# %%
# Specify country and get cleaned data for that country
country = 'Nigeria'
vis_data = clean_country_data(country, dataset)

# %%
# Run grand pipeline based on country data
result = run(vis_data, tune=False)
# Out:
# Data Visualization
# ==============================
# Visualize Data:
# ===============
#
# Stationarity Test
# ==============================
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Augumented Dickey-Fuller Test: Emissions (CH4)
#
# Test Statistic               -1.210884
# p-value                       0.668896
# No. of lags Used              7.000000
# No. of obsv used             12.000000
# Confidence Interval (1%)     -4.137829
# Confidence Interval (5%)     -3.154972
# Confidence Interval (10%)    -2.714477
# dtype: float64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Augumented Dickey-Fuller Test: Emissions (CO2)
#
# Test Statistic               -1.260850
# p-value                       0.646888
# No. of lags Used              7.000000
# No. of obsv used             12.000000
# Confidence Interval (1%)     -4.137829
# Confidence Interval (5%)     -3.154972
# Confidence Interval (10%)    -2.714477
# dtype: float64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Augumented Dickey-Fuller Test: Emissions (N2O)
#
# Test Statistic               -2.416367
# p-value                       0.137170
# No. of lags Used              2.000000
# No. of obsv used             17.000000
# Confidence Interval (1%)     -3.889266
# Confidence Interval (5%)     -3.054358
# Confidence Interval (10%)    -2.666984
# dtype: float64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# Granger Causality Test
# ==============================
# Emissions (CH4) causes Emissions (CO2)?
#  _ _ _ _ _ _ _ _ _ _ _
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.7534  , p=0.0695  , df_denom=17, df_num=1
# ssr based chi2 test:   chi2=4.4158  , p=0.0356  , df=1
# likelihood ratio test: chi2=3.9899  , p=0.0458  , df=1
# parameter F test:         F=3.7534  , p=0.0695  , df_denom=17, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.5478  , p=0.0567  , df_denom=14, df_num=2
# ssr based chi2 test:   chi2=9.6297  , p=0.0081  , df=2
# likelihood ratio test: chi2=7.7901  , p=0.0203  , df=2
# parameter F test:         F=3.5478  , p=0.0567  , df_denom=14, df_num=2
# ==============================
#
# Emissions (CH4) causes Emissions (N2O)?
#  _ _ _ _ _ _ _ _ _ _ _
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.6841  , p=0.0450  , df_denom=17, df_num=1
# ssr based chi2 test:   chi2=5.5108  , p=0.0189  , df=1
# likelihood ratio test: chi2=4.8674  , p=0.0274  , df=1
# parameter F test:         F=4.6841  , p=0.0450  , df_denom=17, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.3732  , p=0.0335  , df_denom=14, df_num=2
# ssr based chi2 test:   chi2=11.8701 , p=0.0026  , df=2
# likelihood ratio test: chi2=9.2216  , p=0.0099  , df=2
# parameter F test:         F=4.3732  , p=0.0335  , df_denom=14, df_num=2
# ==============================
#
# Emissions (CO2) causes Emissions (CH4)?
#  _ _ _ _ _ _ _ _ _ _ _
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3093  , p=0.5853  , df_denom=17, df_num=1
# ssr based chi2 test:   chi2=0.3639  , p=0.5463  , df=1
# likelihood ratio test: chi2=0.3606  , p=0.5482  , df=1
# parameter F test:         F=0.3093  , p=0.5853  , df_denom=17, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8834  , p=0.4352  , df_denom=14, df_num=2
# ssr based chi2 test:   chi2=2.3978  , p=0.3015  , df=2
# likelihood ratio test: chi2=2.2581  , p=0.3233  , df=2
# parameter F test:         F=0.8834  , p=0.4352  , df_denom=14, df_num=2
# ==============================
#
# Emissions (CO2) causes Emissions (N2O)?
#  _ _ _ _ _ _ _ _ _ _ _
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.4319  , p=0.0323  , df_denom=17, df_num=1
# ssr based chi2 test:   chi2=6.3905  , p=0.0115  , df=1
# likelihood ratio test: chi2=5.5454  , p=0.0185  , df=1
# parameter F test:         F=5.4319  , p=0.0323  , df_denom=17, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.9961  , p=0.0826  , df_denom=14, df_num=2
# ssr based chi2 test:   chi2=8.1322  , p=0.0171  , df=2
# likelihood ratio test: chi2=6.7694  , p=0.0339  , df=2
# parameter F test:         F=2.9961  , p=0.0826  , df_denom=14, df_num=2
# ==============================
#
# Emissions (N2O) causes Emissions (CH4)?
#  _ _ _ _ _ _ _ _ _ _ _
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.2055  , p=0.1558  , df_denom=17, df_num=1
# ssr based chi2 test:   chi2=2.5947  , p=0.1072  , df=1
# likelihood ratio test: chi2=2.4397  , p=0.1183  , df=1
# parameter F test:         F=2.2055  , p=0.1558  , df_denom=17, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1517  , p=0.8606  , df_denom=14, df_num=2
# ssr based chi2 test:   chi2=0.4118  , p=0.8139  , df=2
# likelihood ratio test: chi2=0.4074  , p=0.8157  , df=2
# parameter F test:         F=0.1517  , p=0.8606  , df_denom=14, df_num=2
# ==============================
#
# Emissions (N2O) causes Emissions (CO2)?
#  _ _ _ _ _ _ _ _ _ _ _
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3106  , p=0.5846  , df_denom=17, df_num=1
# ssr based chi2 test:   chi2=0.3654  , p=0.5455  , df=1
# likelihood ratio test: chi2=0.3621  , p=0.5473  , df=1
# parameter F test:         F=0.3106  , p=0.5846  , df_denom=17, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1735  , p=0.8425  , df_denom=14, df_num=2
# ssr based chi2 test:   chi2=0.4710  , p=0.7902  , df=2
# likelihood ratio test: chi2=0.4652  , p=0.7925  , df=2
# parameter F test:         F=0.1735  , p=0.8425  , df_denom=14, df_num=2
# ==============================
#
# Causality Matrix (1 Time Lag):
#                  Emissions (CH4) Emissions (CO2) Emissions (N2O)
# Emissions (CH4)             NaN        0.585345        0.155826
# Emissions (CO2)       0.0694966             NaN        0.584566
# Emissions (N2O)       0.0449671       0.0323419             NaN
# Causality Matrix (2 Time Lags):
#                  Emissions (CH4) Emissions (CO2) Emissions (N2O)
# Emissions (CH4)             NaN        0.435209         0.86063
# Emissions (CO2)       0.0566973             NaN         0.84249
# Emissions (N2O)       0.0334589       0.0825806             NaN
# train_df:  (18, 3) test_df:  (3, 3)
#
# Model Info:
# ===============
#                                                Statespace Model Results
# =====================================================================================================================
# Dep. Variable:     ['Emissions (CH4)', 'Emissions (CO2)', 'Emissions (N2O)']   No. Observations:                   18
# Model:                                                                VAR(2)   Log Likelihood                -467.734
#                                                                  + intercept   AIC                            989.469
# Date:                                                       Wed, 12 Apr 2023   BIC                           1013.509
# Time:                                                               13:01:17   HQIC                           992.784
# Sample:                                                           01-01-2000
#                                                                 - 01-01-2017
# Covariance Type:                                                         opg
# ===================================================================================
# Ljung-Box (L1) (Q):       0.01, 1.43, 0.17   Jarque-Bera (JB):     0.42, 4.15, 0.20
# Prob(Q):                  0.91, 0.23, 0.68   Prob(JB):             0.81, 0.13, 0.91
# Heteroskedasticity (H):   0.26, 0.38, 1.74   Skew:               -0.17, -0.91, 0.24
# Prob(H) (two-sided):      0.13, 0.26, 0.52   Kurtosis:             2.33, 4.48, 2.80
#                          Results for equation Emissions (CH4)
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# intercept           8830.7305      0.264   3.34e+04      0.000    8830.213    8831.248
# L1.Emissions (CH4)     0.7121      0.807      0.882      0.378      -0.871       2.295
# L1.Emissions (CO2)    -0.0026      0.014     -0.196      0.845      -0.029       0.024
# L1.Emissions (N2O)     8.1649     25.910      0.315      0.753     -42.617      58.947
# L2.Emissions (CH4)    -0.0456      0.456     -0.100      0.920      -0.940       0.849
# L2.Emissions (CO2)     0.0020      0.008      0.247      0.805      -0.014       0.018
# L2.Emissions (N2O)    -1.3839     19.524     -0.071      0.943     -39.650      36.883
#                          Results for equation Emissions (CO2)
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# intercept           9.756e+05        nan        nan        nan         nan         nan
# L1.Emissions (CH4)    11.6383     34.771      0.335      0.738     -56.512      79.789
# L1.Emissions (CO2)     0.4427      1.188      0.373      0.709      -1.886       2.772
# L1.Emissions (N2O)  1032.3697      0.609   1695.157      0.000    1031.176    1033.563
# L2.Emissions (CH4)    -2.2287     34.682     -0.064      0.949     -70.203      65.746
# L2.Emissions (CO2)    -0.3415      0.913     -0.374      0.708      -2.130       1.447
# L2.Emissions (N2O)   234.4934      0.475    493.310      0.000     233.562     235.425
#                          Results for equation Emissions (N2O)
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# intercept             61.4483      3.656     16.807      0.000      54.283      68.614
# L1.Emissions (CH4)    -0.0106      0.023     -0.461      0.645      -0.056       0.035
# L1.Emissions (CO2)     0.0001      0.001      0.179      0.858      -0.001       0.002
# L1.Emissions (N2O)     0.9555      1.308      0.730      0.465      -1.609       3.520
# L2.Emissions (CH4)    -0.0004      0.031     -0.012      0.991      -0.061       0.060
# L2.Emissions (CO2)  2.872e-05      0.000      0.060      0.952      -0.001       0.001
# L2.Emissions (N2O)    -0.0806      1.384     -0.058      0.954      -2.794       2.633
#                                           Error covariance matrix
# ============================================================================================================
#                                                coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# sqrt.var.Emissions (CH4)                  1470.9766      5.062    290.597      0.000    1461.055    1480.898
# sqrt.cov.Emissions (CH4).Emissions (CO2)  8.615e+04      0.021   4.09e+06      0.000    8.61e+04    8.61e+04
# sqrt.var.Emissions (CO2)                  8.226e+04      0.055    1.5e+06      0.000    8.23e+04    8.23e+04
# sqrt.cov.Emissions (CH4).Emissions (N2O)    14.4271     16.455      0.877      0.381     -17.824      46.678
# sqrt.cov.Emissions (CO2).Emissions (N2O)    30.9337     19.800      1.562      0.118      -7.874      69.741
# sqrt.var.Emissions (N2O)                    25.4969     15.332      1.663      0.096      -4.553      55.547
# ============================================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.94e+22. Standard errors may be unstable.
#
# Predictions:
# ===============
#             Emissions (CH4)_predicted  Emissions (CO2)_predicted  \
# 2018-01-01               41023.231929               3.031565e+06
# 2019-01-01               41448.941835               3.036270e+06
# 2020-01-01               41937.903708               3.036853e+06
#
#             Emissions (N2O)_predicted
# 2018-01-01                1063.814951
# 2019-01-01                1077.044450
# 2020-01-01                1086.715346
#
# Visual Evaluation:
# ===============
# ===== Statistical Eval =====
#
# Mean val Emissions (CH4): 40251.2775 -- RMSE: 1364.2692 -- RMSE < 10% Mean:  True
# Mean val Emissions (CO2): 3067217.6172 -- RMSE: 32580.5628 -- RMSE < 10% Mean:  True
# Mean val Emissions (N2O): 1085.2707 -- RMSE: 13.5402 -- RMSE < 10% Mean:  True
# {'Emissions (CH4)': 1364.2692323360172, 'Emissions (CO2)': 32580.56279062867, 'Emissions (N2O)': 13.5402321823468}

# %% [markdown]
# Make forecasts with model

# %%
# Generate forecast data
ten_yr_forecast = forecast_data(result, 2020, 2030)
ten_yr_forecast
# Out:
#             Emissions (CH4)_predicted  Emissions (CO2)_predicted  \
# 2020-01-01               41937.903708               3.036853e+06
# 2021-01-01               42335.363602               3.053332e+06
# 2022-01-01               42565.269776               3.069382e+06
# 2023-01-01               42699.340309               3.073568e+06
# 2024-01-01               42807.321859               3.071248e+06
# 2025-01-01               42890.469996               3.069547e+06
# 2026-01-01               42931.258238               3.068534e+06
# 2027-01-01               42935.060440               3.065660e+06
# 2028-01-01               42919.077258               3.060707e+06
# 2029-01-01               42891.815673               3.055081e+06
# 2030-01-01               42853.210722               3.049501e+06
#
#             Emissions (N2O)_predicted
# 2020-01-01                1086.715346
# 2021-01-01                1089.766308
# 2022-01-01                1089.962883
# 2023-01-01                1090.170379
# 2024-01-01                1089.927073
# 2025-01-01                1088.259602
# 2026-01-01                1085.445507
# 2027-01-01                1082.229035
# 2028-01-01                1078.872557
# 2029-01-01                1075.276700
# 2030-01-01                1071.431091

# %%
# Visualize overlay of existing data and forecast data
visual_forecast(predictions=ten_yr_forecast, vis_data=vis_data, country=country)
